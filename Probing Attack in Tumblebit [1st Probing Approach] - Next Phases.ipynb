# %%
class Channel:
    def __init__(self, user,total_deposit):
        self.deposit = total_deposit
        self.user = user
        self.u2t = total_deposit/2
        self.t2u = total_deposit/2

# %%
class Transaction:
    def __init__(self, sender, receiver, amount, consent):
        self.sender = sender
        self.receiver = receiver
        self.amount = amount
        self.consent = consent

# %%
class Tumbler:
    def __init__(self, balance):
        self.balance = balance
        self.channels = []
        
    def create_channel(self, user, desposit_amount):
        self.balance -= desposit_amount
        user.deposit(desposit_amount) 
        channel = Channel(user,desposit_amount*2)
        self.channels.append(channel)

# %%
class User:
    def __init__(self, user_id, balance):
        self.user_id = user_id
        self.balance = balance
        self.channel_balance = 0

    def deposit(self, amount):
        # Simulate depositing funds into the user's account
        self.balance -= amount
        self.channel_balance = amount
        return f"Deposited {amount} BTC into User {self.user_id}'s PCH account."
    
#     def initiate_tx(transaction):
        

    def withdraw(self, amount):
        # Simulate withdrawing funds from the user's account
        if amount > self.channel_balance:
            return "Insufficient funds."
        else:
            self.balance += amount
            self.channel_balance = 0
            return f"Withdrew {amount} BTC from User {self.user_id}'s PCH account."

# %% [markdown]
# ### TumbleBit Implementation

# %%
import random


'''
Euclid's algorithm for determining the greatest common divisor
Use iteration to make it faster for larger integers
'''
def gcd(a, b):
    while b != 0:
        a, b = b, a % b
    return a

#Euclid's extended algorithm for finding the multiplicative inverse of two numbers
def extended_gcd(a, b):
    if b == 0:
        return a, 1, 0
    else:
        d, x, y = extended_gcd(b, a % b)
        return d, y, x - y * (a // b)

def find_multiplicative_inverse(a, m):
    d, x, y = extended_gcd(a, m)
    if d == 1:
        return (x % m + m) % m  # Ensure the result is positive and less than m
    else:
        raise ValueError("Multiplicative inverse does not exist.")


#returns True if a number is prime else False
def is_prime(num):
    if num == 2:
        return True
    if num < 2 or num % 2 == 0:
        return False
    for n in range(3, int(num**0.5)+2, 2):
        if num % n == 0:
            return False
    return True




def generate_keypair(p, q):
    if not (is_prime(p) and is_prime(q)):
        raise ValueError('Both numbers must be prime.')
    elif p == q:
        raise ValueError('p and q cannot be equal')
    #n = pq
    n = p * q

    #Phi is the totient of n
    phi = (p-1) * (q-1)

    #Choose an integer e such that e and phi(n) are coprime
    e = random.randrange(1, phi)

    #Use Euclid's Algorithm to verify that e and phi(n) are comprime
    g = gcd(e, phi)
    while g != 1:
        e = random.randrange(1, phi)
        g = gcd(e, phi)

    #Use Extended Euclid's Algorithm to generate the private key
    d = find_multiplicative_inverse(e, phi)
    
#     print("KeyGen",e,n,d, phi)
    
    #Return public and private keypair
    #Public key is (e, n) and private key is (d, n)
    return ((e, n), (d, n))




def encrypt(pk, plaintext):
    #Unpack the key into it's components
#     print(pk, plaintext)
    key, n = pk
#     print(key, n)
    #Convert each letter in the plaintext to numbers based on the character using a^b mod m
    cipher = (plaintext ** key) % n
    #Return the array of bytes
    return cipher




def decrypt(pk, ciphertext):
    #Unpack the key into its components
    key, n = pk
    #Generate the plaintext based on the ciphertext and key using a^b mod m
    plain = (ciphertext ** key) % n
    #Return the array of bytes as a string
    return plain

# %%
def find_channel_by_userID(userID, channels):
    for channel in channels:
        if channel.user.user_id == userID:
            return channel
    return None

# %%
def tx_proto_print(*args, sep=' ', end='\n'):
#     debug = True
    debug = False
    if debug:
        output = sep.join(map(str, args)) + end
        print(output, end='')

# %%
def transction_protocol(sender, receiver, tumbler, amount):
    print("\n\n")
    print("***************************************************************")

    print("Sender ID = "+str(sender.user_id))
    print("Receiver ID = "+str(receiver.user_id))
    print("Amount:",amount)
    
    sender_channel = find_channel_by_userID(sender.user_id, tumbler.channels)
    receiver_channel = find_channel_by_userID(receiver.user_id, tumbler.channels)
    
    if amount>sender_channel.u2t:
        print("Smart Contract: TX invalid, sender doesn't have enough balance!")
        return
    
    if amount>receiver_channel.t2u:
        print("Error! ET1: Receiver channel doesn't have enough balance!")
        return
    
    print("Information about Sender and the channel between Sender and Tumbler:")
    print(vars(sender))
    print(vars(sender_channel))
    print("Information about Receiver and the channel between Tumbler and Receiver:")
    print(vars(receiver))
    print(vars(receiver_channel))
    
    tx_proto_print("\n\n")
    tx_proto_print("***************************************************************")
    tx_proto_print("             Tumble Bit Transaction Protocol                   ")
    tx_proto_print("***************************************************************")

    tx_proto_print("TMB = Tumbler (a trustless 3rd party mediator)")
    tx_proto_print("\n\n--------------- Generating (z,c) at TMB ------------------------")
    temp=random.randrange(1000, 1500)
    while(is_prime(temp) != True):
        temp = random.randrange(1, 50)
    p = temp #taking any random no
    q = 197 #taking any random no

    #Generating your public/private keypairs
    public, private = generate_keypair(p, q)
    tx_proto_print("TMB (RSA public key) = ", public ," TMB (RSA private key) = ", private)
    
    while(amount):

        epsilon = random.randrange(1, 50)
        sigma = random.randrange(1, 50)
        tx_proto_print("Sigma = ",sigma,"epsilon = ",epsilon)
        z = decrypt(public, epsilon)
        c = sigma + epsilon


        tx_proto_print("\n\n\n")
        tx_proto_print("-------------- [TMB ---> Receiver Communication]-------------------")
        tx_proto_print("TMB sending (z,c) = (",z,", ",c,") to Receiver")




        tx_proto_print("\n\n\n")
        tx_proto_print("-------------- [Receiver ---> Sender Communication]-------------------")
        tx_proto_print("Blinding the z before sending")
        bf = random.randrange(1, 10)
        tx_proto_print("Blinding factor bf = ", bf,"& send zStar = z*(bf^p.k)")

        e,n = public
        zStar = (z*decrypt(public, bf))%n
        tx_proto_print("Receiver sending zStar Z* to Sender = ",zStar)
        tx_proto_print("verify zStar=",decrypt(public, bf*epsilon))




        tx_proto_print("\n\n\n")
        tx_proto_print("--------------[Sender ---> TMB Communication]-------------------")
        tx_proto_print("Sender request solution of zStar (z*) to TMB for 1 coin")


        epsilonStar=encrypt(private, zStar)
        tx_proto_print("epsilonStar = ",epsilonStar)
        x = random.randrange(1, 500)
        y = hash(x)
        q = epsilonStar + x



        tx_proto_print("Payment solver protocol exchange")
        for x in range(1,5):
            bff = random.randrange(1000, 5000)
            tx_proto_print("Blinding factors bf = ", bf)
        for x in range(1,5):
            temp = random.randrange(1000, 5000)
            tx_proto_print("Fake factors = ", temp)

        tx_proto_print("TMB sends (y,q) = (",y,q,") to Sender, with exchange for 1 coin.")
        sender_channel.u2t -= 1
        sender_channel.t2u += 1
        sender.channel_balance -= 1
        tx_proto_print("User with ID "+str(sender.user_id)+ " sent 1 coin to tumbler successfully")



        tx_proto_print("\n\n\n")
        tx_proto_print("--------------[Sender ---> Receiver Communication]-------------------")
        tx_proto_print("Sender sending epsilonStar to Receiver")
        tx_proto_print("Receiver calculating epsilon from epsilonStar")

        epsilonBob=epsilonStar / bf
        tx_proto_print("calculated epsilon at Receiver = ",epsilonBob)
        tx_proto_print("finding sigma from epsilon at Receiver")

        sigmaBob = c - epsilonBob
        tx_proto_print("sigma at Receiver = ",sigmaBob)



        tx_proto_print("\n\n\n")
        tx_proto_print("--------------[Receiver ---> TMB Communication]---------------------")
        tx_proto_print("Puzzle promise protocol exchange")
        for x in range(1,5):
            bf = random.randrange(1000, 5000)
            tx_proto_print("Blinding factor bf = ", bf," Hash = ",hash(bf))
        for x in range(1,5):
            temp = random.randrange(1000, 5000)
            tx_proto_print("Fake factors = ", temp)
        tx_proto_print("Receiver sending sigma = ",sigmaBob," to get 1 coin")

        receiver_channel.u2t += 1
        receiver_channel.t2u -= 1
        receiver.channel_balance += 1

        tx_proto_print("User with ID "+str(receiver.user_id)+ " recived 1 coin successfully")
        amount-=1

    
    print("\nAfter TX execution:\nInformation about Sender and the channel between Sender and Tumbler:")
    print(vars(sender))
    print(vars(sender_channel))
    print("Information about Receiver and the channel between Tumbler and Receiver:")
    print(vars(receiver))
    print(vars(receiver_channel))

# %%
def simulate_TXs(num_of_txs):
    
    while(num_of_txs):
    
        print("\n\n------------------")

        random_selection = random.sample(users, 2)

        r_sender = random_selection[0]
        r_receiver = random_selection[1]

        r_amount = random.randint(1, 10)

    #     print("\n\n",random_selection)

    #     for i in random_selection:
    #         print(vars(i))


        transction_protocol(sender=r_sender, receiver=r_receiver, tumbler=tumbler, amount = r_amount)
        num_of_txs-=1

# %%
import pandas as pd
from datetime import datetime

number_of_users=27
number_of_probers = 8

tumbler = Tumbler(balance=5000)

users = [User(user_id=i, balance=random.randint(50, 200)) for i in range(1, number_of_users+1)]

probers = [User(user_id=i, balance=random.randint(100, 400)) for i in range(number_of_users+1, number_of_users+number_of_probers+1)]

# attacker =  User(user_id=number_of_users+1, balance=300)

users.extend(probers)


print("\nUsers:")
for i in users:
    print(vars(i))
    
print("\nTumbler Info:")
print(vars(tumbler))

# Users deposit funds
for user in users:
    if user.user_id<=number_of_users:
        desposit_amount=random.randint(10, 30)
        tumbler.create_channel(user, desposit_amount)
    else:
        desposit_amount = int(0.8*user.balance)
        tumbler.create_channel(user, desposit_amount)
        

print("\nUsers (after channel formation):")
for i in users:
    print(vars(i))

    
print("\nTumbler Info (after channel formation):")
print(vars(tumbler))

print("\nChannels with the Tumbler:")
for i in tumbler.channels:
    print(vars(i))
# Out:
# Users:
# {'user_id': 1, 'balance': 133, 'channel_balance': 0}
# {'user_id': 2, 'balance': 89, 'channel_balance': 0}
# {'user_id': 3, 'balance': 68, 'channel_balance': 0}
# {'user_id': 4, 'balance': 172, 'channel_balance': 0}
# {'user_id': 5, 'balance': 149, 'channel_balance': 0}
# {'user_id': 6, 'balance': 115, 'channel_balance': 0}
# {'user_id': 7, 'balance': 74, 'channel_balance': 0}
# {'user_id': 8, 'balance': 82, 'channel_balance': 0}
# {'user_id': 9, 'balance': 178, 'channel_balance': 0}
# {'user_id': 10, 'balance': 71, 'channel_balance': 0}
# {'user_id': 11, 'balance': 95, 'channel_balance': 0}
# {'user_id': 12, 'balance': 109, 'channel_balance': 0}
# {'user_id': 13, 'balance': 140, 'channel_balance': 0}
# {'user_id': 14, 'balance': 73, 'channel_balance': 0}
# {'user_id': 15, 'balance': 198, 'channel_balance': 0}
# {'user_id': 16, 'balance': 123, 'channel_balance': 0}
# {'user_id': 17, 'balance': 114, 'channel_balance': 0}
# {'user_id': 18, 'balance': 120, 'channel_balance': 0}
# {'user_id': 19, 'balance': 175, 'channel_balance': 0}
# {'user_id': 20, 'balance': 117, 'channel_balance': 0}
# {'user_id': 21, 'balance': 76, 'channel_balance': 0}
# {'user_id': 22, 'balance': 77, 'channel_balance': 0}
# {'user_id': 23, 'balance': 133, 'channel_balance': 0}
# {'user_id': 24, 'balance': 103, 'channel_balance': 0}
# {'user_id': 25, 'balance': 164, 'channel_balance': 0}
# {'user_id': 26, 'balance': 61, 'channel_balance': 0}
# {'user_id': 27, 'balance': 115, 'channel_balance': 0}
# {'user_id': 28, 'balance': 276, 'channel_balance': 0}
# {'user_id': 29, 'balance': 324, 'channel_balance': 0}
# {'user_id': 30, 'balance': 219, 'channel_balance': 0}
# {'user_id': 31, 'balance': 294, 'channel_balance': 0}
# {'user_id': 32, 'balance': 354, 'channel_balance': 0}
# {'user_id': 33, 'balance': 263, 'channel_balance': 0}
# {'user_id': 34, 'balance': 150, 'channel_balance': 0}
# {'user_id': 35, 'balance': 256, 'channel_balance': 0}
#
# Tumbler Info:
# {'balance': 5000, 'channels': []}
#
# Users (after channel formation):
# {'user_id': 1, 'balance': 108, 'channel_balance': 25}
# {'user_id': 2, 'balance': 72, 'channel_balance': 17}
# {'user_id': 3, 'balance': 58, 'channel_balance': 10}
# {'user_id': 4, 'balance': 158, 'channel_balance': 14}
# {'user_id': 5, 'balance': 121, 'channel_balance': 28}
# {'user_id': 6, 'balance': 102, 'channel_balance': 13}
# {'user_id': 7, 'balance': 45, 'channel_balance': 29}
# {'user_id': 8, 'balance': 52, 'channel_balance': 30}
# {'user_id': 9, 'balance': 158, 'channel_balance': 20}
# {'user_id': 10, 'balance': 48, 'channel_balance': 23}
# {'user_id': 11, 'balance': 71, 'channel_balance': 24}
# {'user_id': 12, 'balance': 82, 'channel_balance': 27}
# {'user_id': 13, 'balance': 110, 'channel_balance': 30}
# {'user_id': 14, 'balance': 43, 'channel_balance': 30}
# {'user_id': 15, 'balance': 179, 'channel_balance': 19}
# {'user_id': 16, 'balance': 112, 'channel_balance': 11}
# {'user_id': 17, 'balance': 102, 'channel_balance': 12}
# {'user_id': 18, 'balance': 97, 'channel_balance': 23}
# {'user_id': 19, 'balance': 153, 'channel_balance': 22}
# {'user_id': 20, 'balance': 98, 'channel_balance': 19}
# {'user_id': 21, 'balance': 58, 'channel_balance': 18}
# {'user_id': 22, 'balance': 50, 'channel_balance': 27}
# {'user_id': 23, 'balance': 104, 'channel_balance': 29}
# {'user_id': 24, 'balance': 89, 'channel_balance': 14}
# {'user_id': 25, 'balance': 135, 'channel_balance': 29}
# {'user_id': 26, 'balance': 47, 'channel_balance': 14}
# {'user_id': 27, 'balance': 102, 'channel_balance': 13}
# {'user_id': 28, 'balance': 56, 'channel_balance': 220}
# {'user_id': 29, 'balance': 65, 'channel_balance': 259}
# {'user_id': 30, 'balance': 44, 'channel_balance': 175}
# {'user_id': 31, 'balance': 59, 'channel_balance': 235}
# {'user_id': 32, 'balance': 71, 'channel_balance': 283}
# {'user_id': 33, 'balance': 53, 'channel_balance': 210}
# {'user_id': 34, 'balance': 30, 'channel_balance': 120}
# {'user_id': 35, 'balance': 52, 'channel_balance': 204}
#
# Tumbler Info (after channel formation):
# {'balance': 2724, 'channels': [<__main__.Channel object at 0x00000163F314D370>, <__main__.Channel object at 0x00000163F314D460>, <__main__.Channel object at 0x00000163F314D4C0>, <__main__.Channel object at 0x00000163F314D520>, <__main__.Channel object at 0x00000163F314D5B0>, <__main__.Channel object at 0x00000163F314D610>, <__main__.Channel object at 0x00000163F314D670>, <__main__.Channel object at 0x00000163F314D6D0>, <__main__.Channel object at 0x00000163F314D730>, <__main__.Channel object at 0x00000163F314D790>, <__main__.Channel object at 0x00000163F314D7F0>, <__main__.Channel object at 0x00000163F314D850>, <__main__.Channel object at 0x00000163F314D8B0>, <__main__.Channel object at 0x00000163F314D910>, <__main__.Channel object at 0x00000163F314D970>, <__main__.Channel object at 0x00000163F314D9D0>, <__main__.Channel object at 0x00000163F314DA30>, <__main__.Channel object at 0x00000163F314DA90>, <__main__.Channel object at 0x00000163F314DAF0>, <__main__.Channel object at 0x00000163F314DB50>, <__main__.Channel object at 0x00000163F314DBB0>, <__main__.Channel object at 0x00000163F314DC10>, <__main__.Channel object at 0x00000163F314DC70>, <__main__.Channel object at 0x00000163F314DCD0>, <__main__.Channel object at 0x00000163F314DD30>, <__main__.Channel object at 0x00000163F314DD90>, <__main__.Channel object at 0x00000163F314DDF0>, <__main__.Channel object at 0x00000163F314DE50>, <__main__.Channel object at 0x00000163F314DEB0>, <__main__.Channel object at 0x00000163F314DF10>, <__main__.Channel object at 0x00000163F314DF70>, <__main__.Channel object at 0x00000163F314DFD0>, <__main__.Channel object at 0x00000163F314F070>, <__main__.Channel object at 0x00000163F314F0D0>, <__main__.Channel object at 0x00000163F314F130>]}
#
# Channels with the Tumbler:
# {'deposit': 50, 'user': <__main__.User object at 0x00000163F110AD00>, 'u2t': 25.0, 't2u': 25.0}
# {'deposit': 34, 'user': <__main__.User object at 0x00000163F110AB20>, 'u2t': 17.0, 't2u': 17.0}
# {'deposit': 20, 'user': <__main__.User object at 0x00000163F1081D00>, 'u2t': 10.0, 't2u': 10.0}
# {'deposit': 28, 'user': <__main__.User object at 0x00000163F10819D0>, 'u2t': 14.0, 't2u': 14.0}
# {'deposit': 56, 'user': <__main__.User object at 0x00000163F109E6A0>, 'u2t': 28.0, 't2u': 28.0}
# {'deposit': 26, 'user': <__main__.User object at 0x00000163F2F801C0>, 'u2t': 13.0, 't2u': 13.0}
# {'deposit': 58, 'user': <__main__.User object at 0x00000163F312EAC0>, 'u2t': 29.0, 't2u': 29.0}
# {'deposit': 60, 'user': <__main__.User object at 0x00000163F3137C10>, 'u2t': 30.0, 't2u': 30.0}
# {'deposit': 40, 'user': <__main__.User object at 0x00000163F3137C70>, 'u2t': 20.0, 't2u': 20.0}
# {'deposit': 46, 'user': <__main__.User object at 0x00000163F3137CD0>, 'u2t': 23.0, 't2u': 23.0}
# {'deposit': 48, 'user': <__main__.User object at 0x00000163F3137D30>, 'u2t': 24.0, 't2u': 24.0}
# {'deposit': 54, 'user': <__main__.User object at 0x00000163F3137D90>, 'u2t': 27.0, 't2u': 27.0}
# {'deposit': 60, 'user': <__main__.User object at 0x00000163F3137DF0>, 'u2t': 30.0, 't2u': 30.0}
# {'deposit': 60, 'user': <__main__.User object at 0x00000163F3137E50>, 'u2t': 30.0, 't2u': 30.0}
# {'deposit': 38, 'user': <__main__.User object at 0x00000163F3137EB0>, 'u2t': 19.0, 't2u': 19.0}
# {'deposit': 22, 'user': <__main__.User object at 0x00000163F3137F10>, 'u2t': 11.0, 't2u': 11.0}
# {'deposit': 24, 'user': <__main__.User object at 0x00000163F3137F70>, 'u2t': 12.0, 't2u': 12.0}
# {'deposit': 46, 'user': <__main__.User object at 0x00000163F3137FD0>, 'u2t': 23.0, 't2u': 23.0}
# {'deposit': 44, 'user': <__main__.User object at 0x00000163F3147070>, 'u2t': 22.0, 't2u': 22.0}
# {'deposit': 38, 'user': <__main__.User object at 0x00000163F31470D0>, 'u2t': 19.0, 't2u': 19.0}
# {'deposit': 36, 'user': <__main__.User object at 0x00000163F3147130>, 'u2t': 18.0, 't2u': 18.0}
# {'deposit': 54, 'user': <__main__.User object at 0x00000163F3147190>, 'u2t': 27.0, 't2u': 27.0}
# {'deposit': 58, 'user': <__main__.User object at 0x00000163F31471F0>, 'u2t': 29.0, 't2u': 29.0}
# {'deposit': 28, 'user': <__main__.User object at 0x00000163F3147250>, 'u2t': 14.0, 't2u': 14.0}
# {'deposit': 58, 'user': <__main__.User object at 0x00000163F31472B0>, 'u2t': 29.0, 't2u': 29.0}
# {'deposit': 28, 'user': <__main__.User object at 0x00000163F3147310>, 'u2t': 14.0, 't2u': 14.0}
# {'deposit': 26, 'user': <__main__.User object at 0x00000163F3147370>, 'u2t': 13.0, 't2u': 13.0}
# {'deposit': 440, 'user': <__main__.User object at 0x00000163F312E610>, 'u2t': 220.0, 't2u': 220.0}
# {'deposit': 518, 'user': <__main__.User object at 0x00000163F110A2E0>, 'u2t': 259.0, 't2u': 259.0}
# {'deposit': 350, 'user': <__main__.User object at 0x00000163F3147460>, 'u2t': 175.0, 't2u': 175.0}
# {'deposit': 470, 'user': <__main__.User object at 0x00000163F31474C0>, 'u2t': 235.0, 't2u': 235.0}
# {'deposit': 566, 'user': <__main__.User object at 0x00000163F3147520>, 'u2t': 283.0, 't2u': 283.0}
# {'deposit': 420, 'user': <__main__.User object at 0x00000163F3147580>, 'u2t': 210.0, 't2u': 210.0}
# {'deposit': 240, 'user': <__main__.User object at 0x00000163F3147610>, 'u2t': 120.0, 't2u': 120.0}
# {'deposit': 408, 'user': <__main__.User object at 0x00000163F3147670>, 'u2t': 204.0, 't2u': 204.0}

# %%
num_of_txs = random.randint(2, 5)

simulate_TXs(num_of_txs)
# Out:
# ------------------
#
#
#
# ***************************************************************
# Sender ID = 10
# Receiver ID = 32
# Amount: 3
# Information about Sender and the channel between Sender and Tumbler:
# {'user_id': 10, 'balance': 48, 'channel_balance': 23}
# {'deposit': 46, 'user': <__main__.User object at 0x00000163F3137CD0>, 'u2t': 23.0, 't2u': 23.0}
# Information about Receiver and the channel between Tumbler and Receiver:
# {'user_id': 32, 'balance': 71, 'channel_balance': 283}
# {'deposit': 566, 'user': <__main__.User object at 0x00000163F3147520>, 'u2t': 283.0, 't2u': 283.0}
#
# After TX execution:
# Information about Sender and the channel between Sender and Tumbler:
# {'user_id': 10, 'balance': 48, 'channel_balance': 20}
# {'deposit': 46, 'user': <__main__.User object at 0x00000163F3137CD0>, 'u2t': 20.0, 't2u': 26.0}
# Information about Receiver and the channel between Tumbler and Receiver:
# {'user_id': 32, 'balance': 71, 'channel_balance': 286}
# {'deposit': 566, 'user': <__main__.User object at 0x00000163F3147520>, 'u2t': 286.0, 't2u': 280.0}
#
#
# ------------------
#
#
#
# ***************************************************************
# Sender ID = 6
# Receiver ID = 2
# Amount: 1
# Information about Sender and the channel between Sender and Tumbler:
# {'user_id': 6, 'balance': 102, 'channel_balance': 13}
# {'deposit': 26, 'user': <__main__.User object at 0x00000163F2F801C0>, 'u2t': 13.0, 't2u': 13.0}
# Information about Receiver and the channel between Tumbler and Receiver:
# {'user_id': 2, 'balance': 72, 'channel_balance': 17}
# {'deposit': 34, 'user': <__main__.User object at 0x00000163F110AB20>, 'u2t': 17.0, 't2u': 17.0}
#
# After TX execution:
# Information about Sender and the channel between Sender and Tumbler:
# {'user_id': 6, 'balance': 102, 'channel_balance': 12}
# {'deposit': 26, 'user': <__main__.User object at 0x00000163F2F801C0>, 'u2t': 12.0, 't2u': 14.0}
# Information about Receiver and the channel between Tumbler and Receiver:
# {'user_id': 2, 'balance': 72, 'channel_balance': 18}
# {'deposit': 34, 'user': <__main__.User object at 0x00000163F110AB20>, 'u2t': 18.0, 't2u': 16.0}
#
#
# ------------------
#
#
#
# ***************************************************************
# Sender ID = 19
# Receiver ID = 9
# Amount: 1
# Information about Sender and the channel between Sender and Tumbler:
# {'user_id': 19, 'balance': 153, 'channel_balance': 22}
# {'deposit': 44, 'user': <__main__.User object at 0x00000163F3147070>, 'u2t': 22.0, 't2u': 22.0}
# Information about Receiver and the channel between Tumbler and Receiver:
# {'user_id': 9, 'balance': 158, 'channel_balance': 20}
# {'deposit': 40, 'user': <__main__.User object at 0x00000163F3137C70>, 'u2t': 20.0, 't2u': 20.0}
#
# After TX execution:
# Information about Sender and the channel between Sender and Tumbler:
# {'user_id': 19, 'balance': 153, 'channel_balance': 21}
# {'deposit': 44, 'user': <__main__.User object at 0x00000163F3147070>, 'u2t': 21.0, 't2u': 23.0}
# Information about Receiver and the channel between Tumbler and Receiver:
# {'user_id': 9, 'balance': 158, 'channel_balance': 21}
# {'deposit': 40, 'user': <__main__.User object at 0x00000163F3137C70>, 'u2t': 21.0, 't2u': 19.0}
#
#
# ------------------
#
#
#
# ***************************************************************
# Sender ID = 7
# Receiver ID = 21
# Amount: 6
# Information about Sender and the channel between Sender and Tumbler:
# {'user_id': 7, 'balance': 45, 'channel_balance': 29}
# {'deposit': 58, 'user': <__main__.User object at 0x00000163F312EAC0>, 'u2t': 29.0, 't2u': 29.0}
# Information about Receiver and the channel between Tumbler and Receiver:
# {'user_id': 21, 'balance': 58, 'channel_balance': 18}
# {'deposit': 36, 'user': <__main__.User object at 0x00000163F3147130>, 'u2t': 18.0, 't2u': 18.0}
#
# After TX execution:
# Information about Sender and the channel between Sender and Tumbler:
# {'user_id': 7, 'balance': 45, 'channel_balance': 23}
# {'deposit': 58, 'user': <__main__.User object at 0x00000163F312EAC0>, 'u2t': 23.0, 't2u': 35.0}
# Information about Receiver and the channel between Tumbler and Receiver:
# {'user_id': 21, 'balance': 58, 'channel_balance': 24}
# {'deposit': 36, 'user': <__main__.User object at 0x00000163F3147130>, 'u2t': 24.0, 't2u': 12.0}
#
#
# ------------------
#
#
#
# ***************************************************************
# Sender ID = 34
# Receiver ID = 26
# Amount: 3
# Information about Sender and the channel between Sender and Tumbler:
# {'user_id': 34, 'balance': 30, 'channel_balance': 120}
# {'deposit': 240, 'user': <__main__.User object at 0x00000163F3147610>, 'u2t': 120.0, 't2u': 120.0}
# Information about Receiver and the channel between Tumbler and Receiver:
# {'user_id': 26, 'balance': 47, 'channel_balance': 14}
# {'deposit': 28, 'user': <__main__.User object at 0x00000163F3147310>, 'u2t': 14.0, 't2u': 14.0}
#
# After TX execution:
# Information about Sender and the channel between Sender and Tumbler:
# {'user_id': 34, 'balance': 30, 'channel_balance': 117}
# {'deposit': 240, 'user': <__main__.User object at 0x00000163F3147610>, 'u2t': 117.0, 't2u': 123.0}
# Information about Receiver and the channel between Tumbler and Receiver:
# {'user_id': 26, 'balance': 47, 'channel_balance': 17}
# {'deposit': 28, 'user': <__main__.User object at 0x00000163F3147310>, 'u2t': 17.0, 't2u': 11.0}

# %%
def balance_probing(attacker, victims, tumbler, df):
    
    amount_per_probing = attacker.channel_balance/len(victims)
    print("Attacker Info:",vars(attacker))
#     print(amount)
    for victim in victims:
        amount = amount_per_probing
    
        count=0
        low=0
        high = 0
        print("\n\n---------\nVictim Info:",vars(victim))
        while(True):
#             print("\nPretend sending ",amount)
            fake_TX = Transaction(sender=attacker, receiver=victim, amount=amount, consent=False)
            count+=1
            if amount==(victim.channel_balance):
                print("Discovered Amount:",amount)
                timestamp = datetime.now().strftime("%Y%m%d%H%M%S%f")
                df = df.append({'Time': timestamp, 'User ID': victim.user_id, 'Balance': amount, '# of Probing TXs': count}, ignore_index=True)
                break
            elif amount<(victim.channel_balance):
                low=amount
#                 print("Error: \"Fake TX!\" from Alice")
            else:
                high=amount
#                 print("Error: \"Not enough fund!\" from Tumbler")
            amount=int((low+high)/2)
        
     
        print("# of probing TX performed:",count,"\n---------\n")
    return df

# %%
def split_list_into_sublists(lst, x):
    # Calculate the size of each sublist
    sublist_size = len(lst) // x
    remainder = len(lst) % x

    sublists = []
    start_index = 0

    # Create sublists
    for i in range(x):
        sublist_length = sublist_size + (1 if i < remainder else 0)
        sublists.append(lst[start_index:start_index + sublist_length])
        start_index += sublist_length

    return sublists

# %%
def probing_attack(name):
    # Create an empty DataFrame
    df = pd.DataFrame(columns=['Time', 'User ID', 'Balance', '# of Probing TXs'])


    IDs_of_users = list(range(0, number_of_users))

    # Assigns subsets of users for different probers
    assignments = split_list_into_sublists(IDs_of_users, number_of_probers)

    attacker_id = probers[0].user_id

    for victim_subset in assignments:
        victims = []
        attacker = users[attacker_id-1]
        for victim_id in victim_subset:
            victims.append(users[victim_id])
        df = balance_probing(attacker, victims, tumbler, df)
        attacker_id+=1

    timestamp = datetime.now().strftime("%Y-%m-%d_%H-%M-%S-%f")
    filename = f"{name}_{timestamp}.xlsx"
    df.to_excel(filename, index=False)

# %%
num_of_txs = random.randint(5, 10)
simulate_TXs(num_of_txs)

probing_attack("Discovery")

num_of_txs = random.randint(5, 10)
simulate_TXs(num_of_txs)

probing_attack("Tracking-1")

num_of_txs = random.randint(5, 10)
simulate_TXs(num_of_txs)

probing_attack("Tracking-2")
# Out:
# ------------------
#
#
#
# ***************************************************************
# Sender ID = 3
# Receiver ID = 27
# Amount: 4
# Information about Sender and the channel between Sender and Tumbler:
# {'user_id': 3, 'balance': 58, 'channel_balance': 10}
# {'deposit': 20, 'user': <__main__.User object at 0x00000163F1081D00>, 'u2t': 10.0, 't2u': 10.0}
# Information about Receiver and the channel between Tumbler and Receiver:
# {'user_id': 27, 'balance': 102, 'channel_balance': 13}
# {'deposit': 26, 'user': <__main__.User object at 0x00000163F3147370>, 'u2t': 13.0, 't2u': 13.0}
#
# After TX execution:
# Information about Sender and the channel between Sender and Tumbler:
# {'user_id': 3, 'balance': 58, 'channel_balance': 6}
# {'deposit': 20, 'user': <__main__.User object at 0x00000163F1081D00>, 'u2t': 6.0, 't2u': 14.0}
# Information about Receiver and the channel between Tumbler and Receiver:
# {'user_id': 27, 'balance': 102, 'channel_balance': 17}
# {'deposit': 26, 'user': <__main__.User object at 0x00000163F3147370>, 'u2t': 17.0, 't2u': 9.0}
#
#
# ------------------
#
#
#
# ***************************************************************
# Sender ID = 2
# Receiver ID = 33
# Amount: 6
# Information about Sender and the channel between Sender and Tumbler:
# {'user_id': 2, 'balance': 72, 'channel_balance': 18}
# {'deposit': 34, 'user': <__main__.User object at 0x00000163F110AB20>, 'u2t': 18.0, 't2u': 16.0}
# Information about Receiver and the channel between Tumbler and Receiver:
# {'user_id': 33, 'balance': 53, 'channel_balance': 210}
# {'deposit': 420, 'user': <__main__.User object at 0x00000163F3147580>, 'u2t': 210.0, 't2u': 210.0}
#
# After TX execution:
# Information about Sender and the channel between Sender and Tumbler:
# {'user_id': 2, 'balance': 72, 'channel_balance': 12}
# {'deposit': 34, 'user': <__main__.User object at 0x00000163F110AB20>, 'u2t': 12.0, 't2u': 22.0}
# Information about Receiver and the channel between Tumbler and Receiver:
# {'user_id': 33, 'balance': 53, 'channel_balance': 216}
# {'deposit': 420, 'user': <__main__.User object at 0x00000163F3147580>, 'u2t': 216.0, 't2u': 204.0}
#
#
# ------------------
#
#
#
# ***************************************************************
# Sender ID = 1
# Receiver ID = 35
# Amount: 8
# Information about Sender and the channel between Sender and Tumbler:
# {'user_id': 1, 'balance': 108, 'channel_balance': 25}
# {'deposit': 50, 'user': <__main__.User object at 0x00000163F110AD00>, 'u2t': 25.0, 't2u': 25.0}
# Information about Receiver and the channel between Tumbler and Receiver:
# {'user_id': 35, 'balance': 52, 'channel_balance': 204}
# {'deposit': 408, 'user': <__main__.User object at 0x00000163F3147670>, 'u2t': 204.0, 't2u': 204.0}
#
# After TX execution:
# Information about Sender and the channel between Sender and Tumbler:
# {'user_id': 1, 'balance': 108, 'channel_balance': 17}
# {'deposit': 50, 'user': <__main__.User object at 0x00000163F110AD00>, 'u2t': 17.0, 't2u': 33.0}
# Information about Receiver and the channel between Tumbler and Receiver:
# {'user_id': 35, 'balance': 52, 'channel_balance': 212}
# {'deposit': 408, 'user': <__main__.User object at 0x00000163F3147670>, 'u2t': 212.0, 't2u': 196.0}
#
#
# ------------------
#
#
#
# ***************************************************************
# Sender ID = 20
# Receiver ID = 9
# Amount: 5
# Information about Sender and the channel between Sender and Tumbler:
# {'user_id': 20, 'balance': 98, 'channel_balance': 19}
# {'deposit': 38, 'user': <__main__.User object at 0x00000163F31470D0>, 'u2t': 19.0, 't2u': 19.0}
# Information about Receiver and the channel between Tumbler and Receiver:
# {'user_id': 9, 'balance': 158, 'channel_balance': 21}
# {'deposit': 40, 'user': <__main__.User object at 0x00000163F3137C70>, 'u2t': 21.0, 't2u': 19.0}
#
# After TX execution:
# Information about Sender and the channel between Sender and Tumbler:
# {'user_id': 20, 'balance': 98, 'channel_balance': 14}
# {'deposit': 38, 'user': <__main__.User object at 0x00000163F31470D0>, 'u2t': 14.0, 't2u': 24.0}
# Information about Receiver and the channel between Tumbler and Receiver:
# {'user_id': 9, 'balance': 158, 'channel_balance': 26}
# {'deposit': 40, 'user': <__main__.User object at 0x00000163F3137C70>, 'u2t': 26.0, 't2u': 14.0}
#
#
# ------------------
#
#
#
# ***************************************************************
# Sender ID = 3
# Receiver ID = 7
# Amount: 6
# Information about Sender and the channel between Sender and Tumbler:
# {'user_id': 3, 'balance': 58, 'channel_balance': 6}
# {'deposit': 20, 'user': <__main__.User object at 0x00000163F1081D00>, 'u2t': 6.0, 't2u': 14.0}
# Information about Receiver and the channel between Tumbler and Receiver:
# {'user_id': 7, 'balance': 45, 'channel_balance': 23}
# {'deposit': 58, 'user': <__main__.User object at 0x00000163F312EAC0>, 'u2t': 23.0, 't2u': 35.0}
#
# After TX execution:
# Information about Sender and the channel between Sender and Tumbler:
# {'user_id': 3, 'balance': 58, 'channel_balance': 0}
# {'deposit': 20, 'user': <__main__.User object at 0x00000163F1081D00>, 'u2t': 0.0, 't2u': 20.0}
# Information about Receiver and the channel between Tumbler and Receiver:
# {'user_id': 7, 'balance': 45, 'channel_balance': 29}
# {'deposit': 58, 'user': <__main__.User object at 0x00000163F312EAC0>, 'u2t': 29.0, 't2u': 29.0}
#
#
# ------------------
#
#
#
# ***************************************************************
# Sender ID = 16
# Receiver ID = 29
# Amount: 4
# Information about Sender and the channel between Sender and Tumbler:
# {'user_id': 16, 'balance': 112, 'channel_balance': 11}
# {'deposit': 22, 'user': <__main__.User object at 0x00000163F3137F10>, 'u2t': 11.0, 't2u': 11.0}
# Information about Receiver and the channel between Tumbler and Receiver:
# {'user_id': 29, 'balance': 65, 'channel_balance': 259}
# {'deposit': 518, 'user': <__main__.User object at 0x00000163F110A2E0>, 'u2t': 259.0, 't2u': 259.0}
#
# After TX execution:
# Information about Sender and the channel between Sender and Tumbler:
# {'user_id': 16, 'balance': 112, 'channel_balance': 7}
# {'deposit': 22, 'user': <__main__.User object at 0x00000163F3137F10>, 'u2t': 7.0, 't2u': 15.0}
# Information about Receiver and the channel between Tumbler and Receiver:
# {'user_id': 29, 'balance': 65, 'channel_balance': 263}
# {'deposit': 518, 'user': <__main__.User object at 0x00000163F110A2E0>, 'u2t': 263.0, 't2u': 255.0}
#
#
# ------------------
#
#
#
# ***************************************************************
# Sender ID = 32
# Receiver ID = 12
# Amount: 1
# Information about Sender and the channel between Sender and Tumbler:
# {'user_id': 32, 'balance': 71, 'channel_balance': 286}
# {'deposit': 566, 'user': <__main__.User object at 0x00000163F3147520>, 'u2t': 286.0, 't2u': 280.0}
# Information about Receiver and the channel between Tumbler and Receiver:
# {'user_id': 12, 'balance': 82, 'channel_balance': 27}
# {'deposit': 54, 'user': <__main__.User object at 0x00000163F3137D90>, 'u2t': 27.0, 't2u': 27.0}
#
# After TX execution:
# Information about Sender and the channel between Sender and Tumbler:
# {'user_id': 32, 'balance': 71, 'channel_balance': 285}
# {'deposit': 566, 'user': <__main__.User object at 0x00000163F3147520>, 'u2t': 285.0, 't2u': 281.0}
# Information about Receiver and the channel between Tumbler and Receiver:
# {'user_id': 12, 'balance': 82, 'channel_balance': 28}
# {'deposit': 54, 'user': <__main__.User object at 0x00000163F3137D90>, 'u2t': 28.0, 't2u': 26.0}
#
#
# ------------------
#
#
#
# ***************************************************************
# Sender ID = 22
# Receiver ID = 15
# Amount: 5
# Information about Sender and the channel between Sender and Tumbler:
# {'user_id': 22, 'balance': 50, 'channel_balance': 27}
# {'deposit': 54, 'user': <__main__.User object at 0x00000163F3147190>, 'u2t': 27.0, 't2u': 27.0}
# Information about Receiver and the channel between Tumbler and Receiver:
# {'user_id': 15, 'balance': 179, 'channel_balance': 19}
# {'deposit': 38, 'user': <__main__.User object at 0x00000163F3137EB0>, 'u2t': 19.0, 't2u': 19.0}
#
# After TX execution:
# Information about Sender and the channel between Sender and Tumbler:
# {'user_id': 22, 'balance': 50, 'channel_balance': 22}
# {'deposit': 54, 'user': <__main__.User object at 0x00000163F3147190>, 'u2t': 22.0, 't2u': 32.0}
# Information about Receiver and the channel between Tumbler and Receiver:
# {'user_id': 15, 'balance': 179, 'channel_balance': 24}
# {'deposit': 38, 'user': <__main__.User object at 0x00000163F3137EB0>, 'u2t': 24.0, 't2u': 14.0}
#
#
# ------------------
#
#
#
# ***************************************************************
# Sender ID = 24
# Receiver ID = 29
# Amount: 5
# Information about Sender and the channel between Sender and Tumbler:
# {'user_id': 24, 'balance': 89, 'channel_balance': 14}
# {'deposit': 28, 'user': <__main__.User object at 0x00000163F3147250>, 'u2t': 14.0, 't2u': 14.0}
# Information about Receiver and the channel between Tumbler and Receiver:
# {'user_id': 29, 'balance': 65, 'channel_balance': 263}
# {'deposit': 518, 'user': <__main__.User object at 0x00000163F110A2E0>, 'u2t': 263.0, 't2u': 255.0}
#
# After TX execution:
# Information about Sender and the channel between Sender and Tumbler:
# {'user_id': 24, 'balance': 89, 'channel_balance': 9}
# {'deposit': 28, 'user': <__main__.User object at 0x00000163F3147250>, 'u2t': 9.0, 't2u': 19.0}
# Information about Receiver and the channel between Tumbler and Receiver:
# {'user_id': 29, 'balance': 65, 'channel_balance': 268}
# {'deposit': 518, 'user': <__main__.User object at 0x00000163F110A2E0>, 'u2t': 268.0, 't2u': 250.0}
#
#
# ------------------
#
#
#
# ***************************************************************
# Sender ID = 14
# Receiver ID = 9
# Amount: 6
# Information about Sender and the channel between Sender and Tumbler:
# {'user_id': 14, 'balance': 43, 'channel_balance': 30}
# {'deposit': 60, 'user': <__main__.User object at 0x00000163F3137E50>, 'u2t': 30.0, 't2u': 30.0}
# Information about Receiver and the channel between Tumbler and Receiver:
# {'user_id': 9, 'balance': 158, 'channel_balance': 26}
# {'deposit': 40, 'user': <__main__.User object at 0x00000163F3137C70>, 'u2t': 26.0, 't2u': 14.0}
#
# After TX execution:
# Information about Sender and the channel between Sender and Tumbler:
# {'user_id': 14, 'balance': 43, 'channel_balance': 24}
# {'deposit': 60, 'user': <__main__.User object at 0x00000163F3137E50>, 'u2t': 24.0, 't2u': 36.0}
# Information about Receiver and the channel between Tumbler and Receiver:
# {'user_id': 9, 'balance': 158, 'channel_balance': 32}
# {'deposit': 40, 'user': <__main__.User object at 0x00000163F3137C70>, 'u2t': 32.0, 't2u': 8.0}
# Attacker Info: {'user_id': 28, 'balance': 56, 'channel_balance': 220}
#
#
# ---------
# Victim Info: {'user_id': 1, 'balance': 108, 'channel_balance': 17}
# Discovered Amount: 17
# # of probing TX performed: 7
# ---------
#
#
#
# ---------
# Victim Info: {'user_id': 2, 'balance': 72, 'channel_balance': 12}
# Discovered Amount: 12
# # of probing TX performed: 7
# ---------
#
#
#
# ---------
# Victim Info: {'user_id': 3, 'balance': 58, 'channel_balance': 0}
# Discovered Amount: 0
# # of probing TX performed: 7
# ---------
#
#
#
# ---------
# Victim Info: {'user_id': 4, 'balance': 158, 'channel_balance': 14}
# Discovered Amount: 14
# # of probing TX performed: 6
# ---------
#
# Attacker Info: {'user_id': 29, 'balance': 65, 'channel_balance': 268}
#
#
# ---------
# Victim Info: {'user_id': 5, 'balance': 121, 'channel_balance': 28}
# Discovered Amount: 28
# # of probing TX performed: 5
# ---------
#
#
#
# ---------
# Victim Info: {'user_id': 6, 'balance': 102, 'channel_balance': 12}
# Discovered Amount: 12
# # of probing TX performed: 5
# ---------
#
#
#
# ---------
# Victim Info: {'user_id': 7, 'balance': 45, 'channel_balance': 29}
# Discovered Amount: 29
# # of probing TX performed: 7
# ---------
#
#
#
# ---------
# Victim Info: {'user_id': 8, 'balance': 52, 'channel_balance': 30}
# Discovered Amount: 30
# # of probing TX performed: 6
# ---------
#
# Attacker Info: {'user_id': 30, 'balance': 44, 'channel_balance': 175}
#
#
# ---------
# Victim Info: {'user_id': 9, 'balance': 158, 'channel_balance': 32}
# Discovered Amount: 32
# # of probing TX performed: 3
# ---------
#
#
#
# ---------
# Victim Info: {'user_id': 10, 'balance': 48, 'channel_balance': 20}
# Discovered Amount: 20
# # of probing TX performed: 7
# ---------
#
#
#
# ---------
# Victim Info: {'user_id': 11, 'balance': 71, 'channel_balance': 24}
# Discovered Amount: 24
# # of probing TX performed: 6
# ---------
#
#
#
# ---------
# Victim Info: {'user_id': 12, 'balance': 82, 'channel_balance': 28}
# Discovered Amount: 28
# # of probing TX performed: 7
# ---------
#
# Attacker Info: {'user_id': 31, 'balance': 59, 'channel_balance': 235}
#
#
# ---------
# Victim Info: {'user_id': 13, 'balance': 110, 'channel_balance': 30}
# Discovered Amount: 30
# # of probing TX performed: 7
# ---------
#
#
#
# ---------
# Victim Info: {'user_id': 14, 'balance': 43, 'channel_balance': 24}
# Discovered Amount: 24
# # of probing TX performed: 5
# ---------
#
#
#
# ---------
# Victim Info: {'user_id': 15, 'balance': 179, 'channel_balance': 24}
# Discovered Amount: 24
# # of probing TX performed: 5
# ---------
#
# Attacker Info: {'user_id': 32, 'balance': 71, 'channel_balance': 285}
#
#
# ---------
# Victim Info: {'user_id': 16, 'balance': 112, 'channel_balance': 7}
# Discovered Amount: 7
# # of probing TX performed: 8
# ---------
#
#
#
# ---------
# Victim Info: {'user_id': 17, 'balance': 102, 'channel_balance': 12}
# Discovered Amount: 12
# # of probing TX performed: 7
# ---------
#
#
#
# ---------
# Victim Info: {'user_id': 18, 'balance': 97, 'channel_balance': 23}
# Discovered Amount: 23
# # of probing TX performed: 3
# ---------
#
# Attacker Info: {'user_id': 33, 'balance': 53, 'channel_balance': 216}
#
#
# ---------
# Victim Info: {'user_id': 19, 'balance': 153, 'channel_balance': 21}
# Discovered Amount: 21
# # of probing TX performed: 7
# ---------
#
#
#
# ---------
# Victim Info: {'user_id': 20, 'balance': 98, 'channel_balance': 14}
# Discovered Amount: 14
# # of probing TX performed: 7
# ---------
#
#
#
# ---------
# Victim Info: {'user_id': 21, 'balance': 58, 'channel_balance': 24}
# Discovered Amount: 24
# # of probing TX performed: 6
# ---------
#
# Attacker Info: {'user_id': 34, 'balance': 30, 'channel_balance': 117}
#
#
# ---------
# Victim Info: {'user_id': 22, 'balance': 50, 'channel_balance': 22}
# Discovered Amount: 22
# # of probing TX performed: 6
# ---------
#
#
#
# ---------
# Victim Info: {'user_id': 23, 'balance': 104, 'channel_balance': 29}
# Discovered Amount: 29
# # of probing TX performed: 3
# ---------
#
#
#
# ---------
# Victim Info: {'user_id': 24, 'balance': 89, 'channel_balance': 9}
# Discovered Amount: 9
# # of probing TX performed: 3
# ---------
#
# Attacker Info: {'user_id': 35, 'balance': 52, 'channel_balance': 212}
#
#
# ---------
# Victim Info: {'user_id': 25, 'balance': 135, 'channel_balance': 29}
# Discovered Amount: 29
# # of probing TX performed: 7
# ---------
#
#
#
# ---------
# Victim Info: {'user_id': 26, 'balance': 47, 'channel_balance': 17}
# Discovered Amount: 17
# # of probing TX performed: 3
# ---------
#
#
#
# ---------
# Victim Info: {'user_id': 27, 'balance': 102, 'channel_balance': 17}
# Discovered Amount: 17
# # of probing TX performed: 3
# ---------
#
#
#
# ------------------
#
#
#
# ***************************************************************
# Sender ID = 29
# Receiver ID = 33
# Amount: 4
# Information about Sender and the channel between Sender and Tumbler:
# {'user_id': 29, 'balance': 65, 'channel_balance': 268}
# {'deposit': 518, 'user': <__main__.User object at 0x00000163F110A2E0>, 'u2t': 268.0, 't2u': 250.0}
# Information about Receiver and the channel between Tumbler and Receiver:
# {'user_id': 33, 'balance': 53, 'channel_balance': 216}
# {'deposit': 420, 'user': <__main__.User object at 0x00000163F3147580>, 'u2t': 216.0, 't2u': 204.0}
# After TX execution:
# Information about Sender and the channel between Sender and Tumbler:
# {'user_id': 29, 'balance': 65, 'channel_balance': 264}
# {'deposit': 518, 'user': <__main__.User object at 0x00000163F110A2E0>, 'u2t': 264.0, 't2u': 254.0}
# Information about Receiver and the channel between Tumbler and Receiver:
# {'user_id': 33, 'balance': 53, 'channel_balance': 220}
# {'deposit': 420, 'user': <__main__.User object at 0x00000163F3147580>, 'u2t': 220.0, 't2u': 200.0}
#
#
# ------------------
#
#
#
# ***************************************************************
# Sender ID = 35
# Receiver ID = 15
# Amount: 6
# Information about Sender and the channel between Sender and Tumbler:
# {'user_id': 35, 'balance': 52, 'channel_balance': 212}
# {'deposit': 408, 'user': <__main__.User object at 0x00000163F3147670>, 'u2t': 212.0, 't2u': 196.0}
# Information about Receiver and the channel between Tumbler and Receiver:
# {'user_id': 15, 'balance': 179, 'channel_balance': 24}
# {'deposit': 38, 'user': <__main__.User object at 0x00000163F3137EB0>, 'u2t': 24.0, 't2u': 14.0}
#
# After TX execution:
# Information about Sender and the channel between Sender and Tumbler:
# {'user_id': 35, 'balance': 52, 'channel_balance': 206}
# {'deposit': 408, 'user': <__main__.User object at 0x00000163F3147670>, 'u2t': 206.0, 't2u': 202.0}
# Information about Receiver and the channel between Tumbler and Receiver:
# {'user_id': 15, 'balance': 179, 'channel_balance': 30}
# {'deposit': 38, 'user': <__main__.User object at 0x00000163F3137EB0>, 'u2t': 30.0, 't2u': 8.0}
#
#
# ------------------
#
#
#
# ***************************************************************
# Sender ID = 2
# Receiver ID = 18
# Amount: 1
# Information about Sender and the channel between Sender and Tumbler:
# {'user_id': 2, 'balance': 72, 'channel_balance': 12}
# {'deposit': 34, 'user': <__main__.User object at 0x00000163F110AB20>, 'u2t': 12.0, 't2u': 22.0}
# Information about Receiver and the channel between Tumbler and Receiver:
# {'user_id': 18, 'balance': 97, 'channel_balance': 23}
# {'deposit': 46, 'user': <__main__.User object at 0x00000163F3137FD0>, 'u2t': 23.0, 't2u': 23.0}
#
# After TX execution:
# Information about Sender and the channel between Sender and Tumbler:
# {'user_id': 2, 'balance': 72, 'channel_balance': 11}
# {'deposit': 34, 'user': <__main__.User object at 0x00000163F110AB20>, 'u2t': 11.0, 't2u': 23.0}
# Information about Receiver and the channel between Tumbler and Receiver:
# {'user_id': 18, 'balance': 97, 'channel_balance': 24}
# {'deposit': 46, 'user': <__main__.User object at 0x00000163F3137FD0>, 'u2t': 24.0, 't2u': 22.0}
#
#
# ------------------
#
#
#
# ***************************************************************
# Sender ID = 16
# Receiver ID = 11
# Amount: 9
# Smart Contract: TX invalid, sender doesn't have enough balance!
#
#
# ------------------
#
#
#
# ***************************************************************
# Sender ID = 12
# Receiver ID = 33
# Amount: 8
# Information about Sender and the channel between Sender and Tumbler:
# {'user_id': 12, 'balance': 82, 'channel_balance': 28}
# {'deposit': 54, 'user': <__main__.User object at 0x00000163F3137D90>, 'u2t': 28.0, 't2u': 26.0}
# Information about Receiver and the channel between Tumbler and Receiver:
# {'user_id': 33, 'balance': 53, 'channel_balance': 220}
# {'deposit': 420, 'user': <__main__.User object at 0x00000163F3147580>, 'u2t': 220.0, 't2u': 200.0}
#
# After TX execution:
# Information about Sender and the channel between Sender and Tumbler:
# {'user_id': 12, 'balance': 82, 'channel_balance': 20}
# {'deposit': 54, 'user': <__main__.User object at 0x00000163F3137D90>, 'u2t': 20.0, 't2u': 34.0}
# Information about Receiver and the channel between Tumbler and Receiver:
# {'user_id': 33, 'balance': 53, 'channel_balance': 228}
# {'deposit': 420, 'user': <__main__.User object at 0x00000163F3147580>, 'u2t': 228.0, 't2u': 192.0}
#
#
# ------------------
#
#
#
# ***************************************************************
# Sender ID = 14
# Receiver ID = 2
# Amount: 3
# Information about Sender and the channel between Sender and Tumbler:
# {'user_id': 14, 'balance': 43, 'channel_balance': 24}
# {'deposit': 60, 'user': <__main__.User object at 0x00000163F3137E50>, 'u2t': 24.0, 't2u': 36.0}
# Information about Receiver and the channel between Tumbler and Receiver:
# {'user_id': 2, 'balance': 72, 'channel_balance': 11}
# {'deposit': 34, 'user': <__main__.User object at 0x00000163F110AB20>, 'u2t': 11.0, 't2u': 23.0}
#
# After TX execution:
# Information about Sender and the channel between Sender and Tumbler:
# {'user_id': 14, 'balance': 43, 'channel_balance': 21}
# {'deposit': 60, 'user': <__main__.User object at 0x00000163F3137E50>, 'u2t': 21.0, 't2u': 39.0}
# Information about Receiver and the channel between Tumbler and Receiver:
# {'user_id': 2, 'balance': 72, 'channel_balance': 14}
# {'deposit': 34, 'user': <__main__.User object at 0x00000163F110AB20>, 'u2t': 14.0, 't2u': 20.0}
#
#
# ------------------
#
#
#
# ***************************************************************
# Sender ID = 23
# Receiver ID = 20
# Amount: 2
# Information about Sender and the channel between Sender and Tumbler:
# {'user_id': 23, 'balance': 104, 'channel_balance': 29}
# {'deposit': 58, 'user': <__main__.User object at 0x00000163F31471F0>, 'u2t': 29.0, 't2u': 29.0}
# Information about Receiver and the channel between Tumbler and Receiver:
# {'user_id': 20, 'balance': 98, 'channel_balance': 14}
# {'deposit': 38, 'user': <__main__.User object at 0x00000163F31470D0>, 'u2t': 14.0, 't2u': 24.0}
#
# After TX execution:
# Information about Sender and the channel between Sender and Tumbler:
# {'user_id': 23, 'balance': 104, 'channel_balance': 27}
# {'deposit': 58, 'user': <__main__.User object at 0x00000163F31471F0>, 'u2t': 27.0, 't2u': 31.0}
# Information about Receiver and the channel between Tumbler and Receiver:
# {'user_id': 20, 'balance': 98, 'channel_balance': 16}
# {'deposit': 38, 'user': <__main__.User object at 0x00000163F31470D0>, 'u2t': 16.0, 't2u': 22.0}
#
#
# ------------------
#
#
#
# ***************************************************************
# Sender ID = 33
# Receiver ID = 29
# Amount: 7
# Information about Sender and the channel between Sender and Tumbler:
# {'user_id': 33, 'balance': 53, 'channel_balance': 228}
# {'deposit': 420, 'user': <__main__.User object at 0x00000163F3147580>, 'u2t': 228.0, 't2u': 192.0}
# Information about Receiver and the channel between Tumbler and Receiver:
# {'user_id': 29, 'balance': 65, 'channel_balance': 264}
# {'deposit': 518, 'user': <__main__.User object at 0x00000163F110A2E0>, 'u2t': 264.0, 't2u': 254.0}
#
# After TX execution:
# Information about Sender and the channel between Sender and Tumbler:
# {'user_id': 33, 'balance': 53, 'channel_balance': 221}
# {'deposit': 420, 'user': <__main__.User object at 0x00000163F3147580>, 'u2t': 221.0, 't2u': 199.0}
# Information about Receiver and the channel between Tumbler and Receiver:
# {'user_id': 29, 'balance': 65, 'channel_balance': 271}
# {'deposit': 518, 'user': <__main__.User object at 0x00000163F110A2E0>, 'u2t': 271.0, 't2u': 247.0}
# Attacker Info: {'user_id': 28, 'balance': 56, 'channel_balance': 220}
#
#
# ---------
# Victim Info: {'user_id': 1, 'balance': 108, 'channel_balance': 17}
# Discovered Amount: 17
# # of probing TX performed: 7
# ---------
#
#
#
# ---------
# Victim Info: {'user_id': 2, 'balance': 72, 'channel_balance': 14}
# Discovered Amount: 14
# # of probing TX performed: 6
# ---------
#
#
#
# ---------
# Victim Info: {'user_id': 3, 'balance': 58, 'channel_balance': 0}
# Discovered Amount: 0
# # of probing TX performed: 7
# ---------
#
#
#
# ---------
# Victim Info: {'user_id': 4, 'balance': 158, 'channel_balance': 14}
# Discovered Amount: 14
# # of probing TX performed: 6
# ---------
#
# Attacker Info: {'user_id': 29, 'balance': 65, 'channel_balance': 271}
#
#
# ---------
# Victim Info: {'user_id': 5, 'balance': 121, 'channel_balance': 28}
# Discovered Amount: 28
# # of probing TX performed: 5
# ---------
#
#
#
# ---------
# Victim Info: {'user_id': 6, 'balance': 102, 'channel_balance': 12}
# Discovered Amount: 12
# # of probing TX performed: 5
# ---------
#
#
#
# ---------
# Victim Info: {'user_id': 7, 'balance': 45, 'channel_balance': 29}
# Discovered Amount: 29
# # of probing TX performed: 7
# ---------
#
#
#
# ---------
# Victim Info: {'user_id': 8, 'balance': 52, 'channel_balance': 30}
# Discovered Amount: 30
# # of probing TX performed: 6
# ---------
#
# Attacker Info: {'user_id': 30, 'balance': 44, 'channel_balance': 175}
#
#
# ---------
# Victim Info: {'user_id': 9, 'balance': 158, 'channel_balance': 32}
# Discovered Amount: 32
# # of probing TX performed: 3
# ---------
#
#
#
# ---------
# Victim Info: {'user_id': 10, 'balance': 48, 'channel_balance': 20}
# Discovered Amount: 20
# # of probing TX performed: 7
# ---------
#
#
#
# ---------
# Victim Info: {'user_id': 11, 'balance': 71, 'channel_balance': 24}
# Discovered Amount: 24
# # of probing TX performed: 6
# ---------
#
#
#
# ---------
# Victim Info: {'user_id': 12, 'balance': 82, 'channel_balance': 20}
# Discovered Amount: 20
# # of probing TX performed: 7
# ---------
#
# Attacker Info: {'user_id': 31, 'balance': 59, 'channel_balance': 235}
#
#
# ---------
# Victim Info: {'user_id': 13, 'balance': 110, 'channel_balance': 30}
# Discovered Amount: 30
# # of probing TX performed: 7
# ---------
#
#
#
# ---------
# Victim Info: {'user_id': 14, 'balance': 43, 'channel_balance': 21}
# Discovered Amount: 21
# # of probing TX performed: 6
# ---------
#
#
#
# ---------
# Victim Info: {'user_id': 15, 'balance': 179, 'channel_balance': 30}
# Discovered Amount: 30
# # of probing TX performed: 7
# ---------
#
# Attacker Info: {'user_id': 32, 'balance': 71, 'channel_balance': 285}
#
#
# ---------
# Victim Info: {'user_id': 16, 'balance': 112, 'channel_balance': 7}
# Discovered Amount: 7
# # of probing TX performed: 8
# ---------
#
#
#
# ---------
# Victim Info: {'user_id': 17, 'balance': 102, 'channel_balance': 12}
# Discovered Amount: 12
# # of probing TX performed: 7
# ---------
#
#
#
# ---------
# Victim Info: {'user_id': 18, 'balance': 97, 'channel_balance': 24}
# Discovered Amount: 24
# # of probing TX performed: 7
# ---------
#
# Attacker Info: {'user_id': 33, 'balance': 53, 'channel_balance': 221}
#
#
# ---------
# Victim Info: {'user_id': 19, 'balance': 153, 'channel_balance': 21}
# Discovered Amount: 21
# # of probing TX performed: 7
# ---------
#
#
#
# ---------
# Victim Info: {'user_id': 20, 'balance': 98, 'channel_balance': 16}
# Discovered Amount: 16
# # of probing TX performed: 7
# ---------
#
#
#
# ---------
# Victim Info: {'user_id': 21, 'balance': 58, 'channel_balance': 24}
# Discovered Amount: 24
# # of probing TX performed: 6
# ---------
#
# Attacker Info: {'user_id': 34, 'balance': 30, 'channel_balance': 117}
#
#
# ---------
# Victim Info: {'user_id': 22, 'balance': 50, 'channel_balance': 22}
# Discovered Amount: 22
# # of probing TX performed: 6
# ---------
#
#
#
# ---------
# Victim Info: {'user_id': 23, 'balance': 104, 'channel_balance': 27}
# Discovered Amount: 27
# # of probing TX performed: 6
# ---------
#
#
#
# ---------
# Victim Info: {'user_id': 24, 'balance': 89, 'channel_balance': 9}
# Discovered Amount: 9
# # of probing TX performed: 3
# ---------
#
# Attacker Info: {'user_id': 35, 'balance': 52, 'channel_balance': 206}
#
#
# ---------
# Victim Info: {'user_id': 25, 'balance': 135, 'channel_balance': 29}
# Discovered Amount: 29
# # of probing TX performed: 5
# ---------
#
#
#
# ---------
# Victim Info: {'user_id': 26, 'balance': 47, 'channel_balance': 17}
# Discovered Amount: 17
# # of probing TX performed: 3
# ---------
#
#
#
# ---------
# Victim Info: {'user_id': 27, 'balance': 102, 'channel_balance': 17}
# Discovered Amount: 17
# # of probing TX performed: 3
# ---------
#
#
#
# ------------------
#
#
#
# ***************************************************************
# Sender ID = 29
# Receiver ID = 16
# Amount: 8
# Information about Sender and the channel between Sender and Tumbler:
# {'user_id': 29, 'balance': 65, 'channel_balance': 271}
# {'deposit': 518, 'user': <__main__.User object at 0x00000163F110A2E0>, 'u2t': 271.0, 't2u': 247.0}
# Information about Receiver and the channel between Tumbler and Receiver:
# {'user_id': 16, 'balance': 112, 'channel_balance': 7}
# {'deposit': 22, 'user': <__main__.User object at 0x00000163F3137F10>, 'u2t': 7.0, 't2u': 15.0}
#
# After TX execution:
# Information about Sender and the channel between Sender and Tumbler:
# {'user_id': 29, 'balance': 65, 'channel_balance': 263}
# {'deposit': 518, 'user': <__main__.User object at 0x00000163F110A2E0>, 'u2t': 263.0, 't2u': 255.0}
# Information about Receiver and the channel between Tumbler and Receiver:
# {'user_id': 16, 'balance': 112, 'channel_balance': 15}
# {'deposit': 22, 'user': <__main__.User object at 0x00000163F3137F10>, 'u2t': 15.0, 't2u': 7.0}
#
#
# ------------------
#
#
#
# ***************************************************************
# Sender ID = 17
# Receiver ID = 21
# Amount: 5
# Information about Sender and the channel between Sender and Tumbler:
# {'user_id': 17, 'balance': 102, 'channel_balance': 12}
# {'deposit': 24, 'user': <__main__.User object at 0x00000163F3137F70>, 'u2t': 12.0, 't2u': 12.0}
# Information about Receiver and the channel between Tumbler and Receiver:
# {'user_id': 21, 'balance': 58, 'channel_balance': 24}
# {'deposit': 36, 'user': <__main__.User object at 0x00000163F3147130>, 'u2t': 24.0, 't2u': 12.0}
#
# After TX execution:
# Information about Sender and the channel between Sender and Tumbler:
# {'user_id': 17, 'balance': 102, 'channel_balance': 7}
# {'deposit': 24, 'user': <__main__.User object at 0x00000163F3137F70>, 'u2t': 7.0, 't2u': 17.0}
# Information about Receiver and the channel between Tumbler and Receiver:
# {'user_id': 21, 'balance': 58, 'channel_balance': 29}
# {'deposit': 36, 'user': <__main__.User object at 0x00000163F3147130>, 'u2t': 29.0, 't2u': 7.0}
#
#
# ------------------
#
#
#
# ***************************************************************
# Sender ID = 8
# Receiver ID = 19
# Amount: 5
# Information about Sender and the channel between Sender and Tumbler:
# {'user_id': 8, 'balance': 52, 'channel_balance': 30}
# {'deposit': 60, 'user': <__main__.User object at 0x00000163F3137C10>, 'u2t': 30.0, 't2u': 30.0}
# Information about Receiver and the channel between Tumbler and Receiver:
# {'user_id': 19, 'balance': 153, 'channel_balance': 21}
# {'deposit': 44, 'user': <__main__.User object at 0x00000163F3147070>, 'u2t': 21.0, 't2u': 23.0}
#
# After TX execution:
# Information about Sender and the channel between Sender and Tumbler:
# {'user_id': 8, 'balance': 52, 'channel_balance': 25}
# {'deposit': 60, 'user': <__main__.User object at 0x00000163F3137C10>, 'u2t': 25.0, 't2u': 35.0}
# Information about Receiver and the channel between Tumbler and Receiver:
# {'user_id': 19, 'balance': 153, 'channel_balance': 26}
# {'deposit': 44, 'user': <__main__.User object at 0x00000163F3147070>, 'u2t': 26.0, 't2u': 18.0}
#
#
# ------------------
#
#
#
# ***************************************************************
# Sender ID = 28
# Receiver ID = 30
# Amount: 9
# Information about Sender and the channel between Sender and Tumbler:
# {'user_id': 28, 'balance': 56, 'channel_balance': 220}
# {'deposit': 440, 'user': <__main__.User object at 0x00000163F312E610>, 'u2t': 220.0, 't2u': 220.0}
# Information about Receiver and the channel between Tumbler and Receiver:
# {'user_id': 30, 'balance': 44, 'channel_balance': 175}
# {'deposit': 350, 'user': <__main__.User object at 0x00000163F3147460>, 'u2t': 175.0, 't2u': 175.0}
# After TX execution:
# Information about Sender and the channel between Sender and Tumbler:
# {'user_id': 28, 'balance': 56, 'channel_balance': 211}
# {'deposit': 440, 'user': <__main__.User object at 0x00000163F312E610>, 'u2t': 211.0, 't2u': 229.0}
# Information about Receiver and the channel between Tumbler and Receiver:
# {'user_id': 30, 'balance': 44, 'channel_balance': 184}
# {'deposit': 350, 'user': <__main__.User object at 0x00000163F3147460>, 'u2t': 184.0, 't2u': 166.0}
#
#
# ------------------
#
#
#
# ***************************************************************
# Sender ID = 22
# Receiver ID = 19
# Amount: 2
# Information about Sender and the channel between Sender and Tumbler:
# {'user_id': 22, 'balance': 50, 'channel_balance': 22}
# {'deposit': 54, 'user': <__main__.User object at 0x00000163F3147190>, 'u2t': 22.0, 't2u': 32.0}
# Information about Receiver and the channel between Tumbler and Receiver:
# {'user_id': 19, 'balance': 153, 'channel_balance': 26}
# {'deposit': 44, 'user': <__main__.User object at 0x00000163F3147070>, 'u2t': 26.0, 't2u': 18.0}
#
# After TX execution:
# Information about Sender and the channel between Sender and Tumbler:
# {'user_id': 22, 'balance': 50, 'channel_balance': 20}
# {'deposit': 54, 'user': <__main__.User object at 0x00000163F3147190>, 'u2t': 20.0, 't2u': 34.0}
# Information about Receiver and the channel between Tumbler and Receiver:
# {'user_id': 19, 'balance': 153, 'channel_balance': 28}
# {'deposit': 44, 'user': <__main__.User object at 0x00000163F3147070>, 'u2t': 28.0, 't2u': 16.0}
#
#
# ------------------
#
#
#
# ***************************************************************
# Sender ID = 22
# Receiver ID = 17
# Amount: 8
# Information about Sender and the channel between Sender and Tumbler:
# {'user_id': 22, 'balance': 50, 'channel_balance': 20}
# {'deposit': 54, 'user': <__main__.User object at 0x00000163F3147190>, 'u2t': 20.0, 't2u': 34.0}
# Information about Receiver and the channel between Tumbler and Receiver:
# {'user_id': 17, 'balance': 102, 'channel_balance': 7}
# {'deposit': 24, 'user': <__main__.User object at 0x00000163F3137F70>, 'u2t': 7.0, 't2u': 17.0}
#
# After TX execution:
# Information about Sender and the channel between Sender and Tumbler:
# {'user_id': 22, 'balance': 50, 'channel_balance': 12}
# {'deposit': 54, 'user': <__main__.User object at 0x00000163F3147190>, 'u2t': 12.0, 't2u': 42.0}
# Information about Receiver and the channel between Tumbler and Receiver:
# {'user_id': 17, 'balance': 102, 'channel_balance': 15}
# {'deposit': 24, 'user': <__main__.User object at 0x00000163F3137F70>, 'u2t': 15.0, 't2u': 9.0}
#
#
# ------------------
#
#
#
# ***************************************************************
# Sender ID = 5
# Receiver ID = 33
# Amount: 2
# Information about Sender and the channel between Sender and Tumbler:
# {'user_id': 5, 'balance': 121, 'channel_balance': 28}
# {'deposit': 56, 'user': <__main__.User object at 0x00000163F109E6A0>, 'u2t': 28.0, 't2u': 28.0}
# Information about Receiver and the channel between Tumbler and Receiver:
# {'user_id': 33, 'balance': 53, 'channel_balance': 221}
# {'deposit': 420, 'user': <__main__.User object at 0x00000163F3147580>, 'u2t': 221.0, 't2u': 199.0}
#
# After TX execution:
# Information about Sender and the channel between Sender and Tumbler:
# {'user_id': 5, 'balance': 121, 'channel_balance': 26}
# {'deposit': 56, 'user': <__main__.User object at 0x00000163F109E6A0>, 'u2t': 26.0, 't2u': 30.0}
# Information about Receiver and the channel between Tumbler and Receiver:
# {'user_id': 33, 'balance': 53, 'channel_balance': 223}
# {'deposit': 420, 'user': <__main__.User object at 0x00000163F3147580>, 'u2t': 223.0, 't2u': 197.0}
#
#
# ------------------
#
#
#
# ***************************************************************
# Sender ID = 21
# Receiver ID = 29
# Amount: 7
# Information about Sender and the channel between Sender and Tumbler:
# {'user_id': 21, 'balance': 58, 'channel_balance': 29}
# {'deposit': 36, 'user': <__main__.User object at 0x00000163F3147130>, 'u2t': 29.0, 't2u': 7.0}
# Information about Receiver and the channel between Tumbler and Receiver:
# {'user_id': 29, 'balance': 65, 'channel_balance': 263}
# {'deposit': 518, 'user': <__main__.User object at 0x00000163F110A2E0>, 'u2t': 263.0, 't2u': 255.0}
#
# After TX execution:
# Information about Sender and the channel between Sender and Tumbler:
# {'user_id': 21, 'balance': 58, 'channel_balance': 22}
# {'deposit': 36, 'user': <__main__.User object at 0x00000163F3147130>, 'u2t': 22.0, 't2u': 14.0}
# Information about Receiver and the channel between Tumbler and Receiver:
# {'user_id': 29, 'balance': 65, 'channel_balance': 270}
# {'deposit': 518, 'user': <__main__.User object at 0x00000163F110A2E0>, 'u2t': 270.0, 't2u': 248.0}
#
#
# ------------------
#
#
#
# ***************************************************************
# Sender ID = 4
# Receiver ID = 19
# Amount: 9
# Information about Sender and the channel between Sender and Tumbler:
# {'user_id': 4, 'balance': 158, 'channel_balance': 14}
# {'deposit': 28, 'user': <__main__.User object at 0x00000163F10819D0>, 'u2t': 14.0, 't2u': 14.0}
# Information about Receiver and the channel between Tumbler and Receiver:
# {'user_id': 19, 'balance': 153, 'channel_balance': 28}
# {'deposit': 44, 'user': <__main__.User object at 0x00000163F3147070>, 'u2t': 28.0, 't2u': 16.0}
#
# After TX execution:
# Information about Sender and the channel between Sender and Tumbler:
# {'user_id': 4, 'balance': 158, 'channel_balance': 5}
# {'deposit': 28, 'user': <__main__.User object at 0x00000163F10819D0>, 'u2t': 5.0, 't2u': 23.0}
# Information about Receiver and the channel between Tumbler and Receiver:
# {'user_id': 19, 'balance': 153, 'channel_balance': 37}
# {'deposit': 44, 'user': <__main__.User object at 0x00000163F3147070>, 'u2t': 37.0, 't2u': 7.0}
# Attacker Info: {'user_id': 28, 'balance': 56, 'channel_balance': 211}
#
#
# ---------
# Victim Info: {'user_id': 1, 'balance': 108, 'channel_balance': 17}
# Discovered Amount: 17
# # of probing TX performed: 6
# ---------
#
#
#
# ---------
# Victim Info: {'user_id': 2, 'balance': 72, 'channel_balance': 14}
# Discovered Amount: 14
# # of probing TX performed: 6
# ---------
#
#
#
# ---------
# Victim Info: {'user_id': 3, 'balance': 58, 'channel_balance': 0}
# Discovered Amount: 0
# # of probing TX performed: 7
# ---------
#
#
#
# ---------
# Victim Info: {'user_id': 4, 'balance': 158, 'channel_balance': 5}
# Discovered Amount: 5
# # of probing TX performed: 7
# ---------
#
# Attacker Info: {'user_id': 29, 'balance': 65, 'channel_balance': 270}
#
#
# ---------
# Victim Info: {'user_id': 5, 'balance': 121, 'channel_balance': 26}
# Discovered Amount: 26
# # of probing TX performed: 6
# ---------
#
#
#
# ---------
# Victim Info: {'user_id': 6, 'balance': 102, 'channel_balance': 12}
# Discovered Amount: 12
# # of probing TX performed: 5
# ---------
#
#
#
# ---------
# Victim Info: {'user_id': 7, 'balance': 45, 'channel_balance': 29}
# Discovered Amount: 29
# # of probing TX performed: 7
# ---------
#
#
#
# ---------
# Victim Info: {'user_id': 8, 'balance': 52, 'channel_balance': 25}
# Discovered Amount: 25
# # of probing TX performed: 7
# ---------
#
# Attacker Info: {'user_id': 30, 'balance': 44, 'channel_balance': 184}
#
#
# ---------
# Victim Info: {'user_id': 9, 'balance': 158, 'channel_balance': 32}
# Discovered Amount: 32
# # of probing TX performed: 6
# ---------
#
#
#
# ---------
# Victim Info: {'user_id': 10, 'balance': 48, 'channel_balance': 20}
# Discovered Amount: 20
# # of probing TX performed: 5
# ---------
#
#
#
# ---------
# Victim Info: {'user_id': 11, 'balance': 71, 'channel_balance': 24}
# Discovered Amount: 24
# # of probing TX performed: 6
# ---------
#
#
#
# ---------
# Victim Info: {'user_id': 12, 'balance': 82, 'channel_balance': 20}
# Discovered Amount: 20
# # of probing TX performed: 5
# ---------
#
# Attacker Info: {'user_id': 31, 'balance': 59, 'channel_balance': 235}
#
#
# ---------
# Victim Info: {'user_id': 13, 'balance': 110, 'channel_balance': 30}
# Discovered Amount: 30
# # of probing TX performed: 7
# ---------
#
#
#
# ---------
# Victim Info: {'user_id': 14, 'balance': 43, 'channel_balance': 21}
# Discovered Amount: 21
# # of probing TX performed: 6
# ---------
#
#
#
# ---------
# Victim Info: {'user_id': 15, 'balance': 179, 'channel_balance': 30}
# Discovered Amount: 30
# # of probing TX performed: 7
# ---------
#
# Attacker Info: {'user_id': 32, 'balance': 71, 'channel_balance': 285}
#
#
# ---------
# Victim Info: {'user_id': 16, 'balance': 112, 'channel_balance': 15}
# Discovered Amount: 15
# # of probing TX performed: 7
# ---------
#
#
#
# ---------
# Victim Info: {'user_id': 17, 'balance': 102, 'channel_balance': 15}
# Discovered Amount: 15
# # of probing TX performed: 7
# ---------
#
#
#
# ---------
# Victim Info: {'user_id': 18, 'balance': 97, 'channel_balance': 24}
# Discovered Amount: 24
# # of probing TX performed: 7
# ---------
#
# Attacker Info: {'user_id': 33, 'balance': 53, 'channel_balance': 223}
#
#
# ---------
# Victim Info: {'user_id': 19, 'balance': 153, 'channel_balance': 37}
# Discovered Amount: 37
# # of probing TX performed: 2
# ---------
#
#
#
# ---------
# Victim Info: {'user_id': 20, 'balance': 98, 'channel_balance': 16}
# Discovered Amount: 16
# # of probing TX performed: 7
# ---------
#
#
#
# ---------
# Victim Info: {'user_id': 21, 'balance': 58, 'channel_balance': 22}
# Discovered Amount: 22
# # of probing TX performed: 5
# ---------
#
# Attacker Info: {'user_id': 34, 'balance': 30, 'channel_balance': 117}
#
#
# ---------
# Victim Info: {'user_id': 22, 'balance': 50, 'channel_balance': 12}
# Discovered Amount: 12
# # of probing TX performed: 6
# ---------
#
#
#
# ---------
# Victim Info: {'user_id': 23, 'balance': 104, 'channel_balance': 27}
# Discovered Amount: 27
# # of probing TX performed: 6
# ---------
#
#
#
# ---------
# Victim Info: {'user_id': 24, 'balance': 89, 'channel_balance': 9}
# Discovered Amount: 9
# # of probing TX performed: 3
# ---------
#
# Attacker Info: {'user_id': 35, 'balance': 52, 'channel_balance': 206}
#
#
# ---------
# Victim Info: {'user_id': 25, 'balance': 135, 'channel_balance': 29}
# Discovered Amount: 29
# # of probing TX performed: 5
# ---------
#
#
#
# ---------
# Victim Info: {'user_id': 26, 'balance': 47, 'channel_balance': 17}
# Discovered Amount: 17
# # of probing TX performed: 3
# ---------
#
#
#
# ---------
# Victim Info: {'user_id': 27, 'balance': 102, 'channel_balance': 17}
# Discovered Amount: 17
# # of probing TX performed: 3
# ---------
