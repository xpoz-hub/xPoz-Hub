# %%
class Channel:
    def __init__(self, user,total_deposit):
        self.deposit = total_deposit
        self.user = user
        self.u2t = total_deposit/2
        self.t2u = total_deposit/2

# %%
class Transaction:
    def __init__(self, sender, receiver, amount, consent):
        self.sender = sender
        self.receiver = receiver
        self.amount = amount
        self.consent = consent

# %%
class Tumbler:
    def __init__(self, balance):
        self.balance = balance
        self.channels = []
        
    def create_channel(self, user, desposit_amount):
        self.balance -= desposit_amount
        user.deposit(desposit_amount) 
        channel = Channel(user,desposit_amount*2)
        self.channels.append(channel)

# %%
class User:
    def __init__(self, user_id, balance):
        self.user_id = user_id
        self.balance = balance
        self.channel_balance = 0

    def deposit(self, amount):
        # Simulate depositing funds into the user's account
        self.balance -= amount
        self.channel_balance = amount
        return f"Deposited {amount} BTC into User {self.user_id}'s PCH account."
    
#     def initiate_tx(transaction):
        

    def withdraw(self, amount):
        # Simulate withdrawing funds from the user's account
        if amount > self.channel_balance:
            return "Insufficient funds."
        else:
            self.balance += amount
            self.channel_balance = 0
            return f"Withdrew {amount} BTC from User {self.user_id}'s PCH account."

# %% [markdown]
# ### TumbleBit Implementation

# %%
import random


'''
Euclid's algorithm for determining the greatest common divisor
Use iteration to make it faster for larger integers
'''
def gcd(a, b):
    while b != 0:
        a, b = b, a % b
    return a

#Euclid's extended algorithm for finding the multiplicative inverse of two numbers
def extended_gcd(a, b):
    if b == 0:
        return a, 1, 0
    else:
        d, x, y = extended_gcd(b, a % b)
        return d, y, x - y * (a // b)

def find_multiplicative_inverse(a, m):
    d, x, y = extended_gcd(a, m)
    if d == 1:
        return (x % m + m) % m  # Ensure the result is positive and less than m
    else:
        raise ValueError("Multiplicative inverse does not exist.")


#returns True if a number is prime else False
def is_prime(num):
    if num == 2:
        return True
    if num < 2 or num % 2 == 0:
        return False
    for n in range(3, int(num**0.5)+2, 2):
        if num % n == 0:
            return False
    return True




def generate_keypair(p, q):
    if not (is_prime(p) and is_prime(q)):
        raise ValueError('Both numbers must be prime.')
    elif p == q:
        raise ValueError('p and q cannot be equal')
    #n = pq
    n = p * q

    #Phi is the totient of n
    phi = (p-1) * (q-1)

    #Choose an integer e such that e and phi(n) are coprime
    e = random.randrange(1, phi)

    #Use Euclid's Algorithm to verify that e and phi(n) are comprime
    g = gcd(e, phi)
    while g != 1:
        e = random.randrange(1, phi)
        g = gcd(e, phi)

    #Use Extended Euclid's Algorithm to generate the private key
    d = find_multiplicative_inverse(e, phi)
    
#     print("KeyGen",e,n,d, phi)
    
    #Return public and private keypair
    #Public key is (e, n) and private key is (d, n)
    return ((e, n), (d, n))




def encrypt(pk, plaintext):
    #Unpack the key into it's components
#     print(pk, plaintext)
    key, n = pk
#     print(key, n)
    #Convert each letter in the plaintext to numbers based on the character using a^b mod m
    cipher = (plaintext ** key) % n
    #Return the array of bytes
    return cipher




def decrypt(pk, ciphertext):
    #Unpack the key into its components
    key, n = pk
    #Generate the plaintext based on the ciphertext and key using a^b mod m
    plain = (ciphertext ** key) % n
    #Return the array of bytes as a string
    return plain

# %%
def find_channel_by_userID(userID, channels):
    for channel in channels:
        if channel.user.user_id == userID:
            return channel
    return None

# %%
def tx_proto_print(*args, sep=' ', end='\n'):
#     debug = True
    debug = False
    if debug:
        output = sep.join(map(str, args)) + end
        print(output, end='')

# %%
def transction_protocol(sender, receiver, tumbler, amount):
    print("\n\n")
    print("***************************************************************")

    print("Sender ID = "+str(sender.user_id))
    print("Receiver ID = "+str(receiver.user_id))
    print("Amount:",amount)
    
    sender_channel = find_channel_by_userID(sender.user_id, tumbler.channels)
    receiver_channel = find_channel_by_userID(receiver.user_id, tumbler.channels)
    
    if amount>sender_channel.u2t:
        print("Smart Contract: TX invalid, sender doesn't have enough balance!")
        return
    
    if amount>receiver_channel.t2u:
        print("Error! ET1: Receiver channel doesn't have enough balance!")
        return
    
    print("Information about Sender and the channel between Sender and Tumbler:")
    print(vars(sender))
    print(vars(sender_channel))
    print("Information about Receiver and the channel between Tumbler and Receiver:")
    print(vars(receiver))
    print(vars(receiver_channel))
    
    tx_proto_print("\n\n")
    tx_proto_print("***************************************************************")
    tx_proto_print("             Tumble Bit Transaction Protocol                   ")
    tx_proto_print("***************************************************************")

    tx_proto_print("TMB = Tumbler (a trustless 3rd party mediator)")
    tx_proto_print("\n\n--------------- Generating (z,c) at TMB ------------------------")
    temp=random.randrange(1000, 1500)
    while(is_prime(temp) != True):
        temp = random.randrange(1, 50)
    p = temp #taking any random no
    q = 197 #taking any random no

    #Generating your public/private keypairs
    public, private = generate_keypair(p, q)
    tx_proto_print("TMB (RSA public key) = ", public ," TMB (RSA private key) = ", private)
    
    while(amount):

        epsilon = random.randrange(1, 50)
        sigma = random.randrange(1, 50)
        tx_proto_print("Sigma = ",sigma,"epsilon = ",epsilon)
        z = decrypt(public, epsilon)
        c = sigma + epsilon


        tx_proto_print("\n\n\n")
        tx_proto_print("-------------- [TMB ---> Receiver Communication]-------------------")
        tx_proto_print("TMB sending (z,c) = (",z,", ",c,") to Receiver")




        tx_proto_print("\n\n\n")
        tx_proto_print("-------------- [Receiver ---> Sender Communication]-------------------")
        tx_proto_print("Blinding the z before sending")
        bf = random.randrange(1, 10)
        tx_proto_print("Blinding factor bf = ", bf,"& send zStar = z*(bf^p.k)")

        e,n = public
        zStar = (z*decrypt(public, bf))%n
        tx_proto_print("Receiver sending zStar Z* to Sender = ",zStar)
        tx_proto_print("verify zStar=",decrypt(public, bf*epsilon))




        tx_proto_print("\n\n\n")
        tx_proto_print("--------------[Sender ---> TMB Communication]-------------------")
        tx_proto_print("Sender request solution of zStar (z*) to TMB for 1 coin")


        epsilonStar=encrypt(private, zStar)
        tx_proto_print("epsilonStar = ",epsilonStar)
        x = random.randrange(1, 500)
        y = hash(x)
        q = epsilonStar + x



        tx_proto_print("Payment solver protocol exchange")
        for x in range(1,5):
            bff = random.randrange(1000, 5000)
            tx_proto_print("Blinding factors bf = ", bf)
        for x in range(1,5):
            temp = random.randrange(1000, 5000)
            tx_proto_print("Fake factors = ", temp)

        tx_proto_print("TMB sends (y,q) = (",y,q,") to Sender, with exchange for 1 coin.")
        sender_channel.u2t -= 1
        sender_channel.t2u += 1
        sender.channel_balance -= 1
        tx_proto_print("User with ID "+str(sender.user_id)+ " sent 1 coin to tumbler successfully")



        tx_proto_print("\n\n\n")
        tx_proto_print("--------------[Sender ---> Receiver Communication]-------------------")
        tx_proto_print("Sender sending epsilonStar to Receiver")
        tx_proto_print("Receiver calculating epsilon from epsilonStar")

        epsilonBob=epsilonStar / bf
        tx_proto_print("calculated epsilon at Receiver = ",epsilonBob)
        tx_proto_print("finding sigma from epsilon at Receiver")

        sigmaBob = c - epsilonBob
        tx_proto_print("sigma at Receiver = ",sigmaBob)



        tx_proto_print("\n\n\n")
        tx_proto_print("--------------[Receiver ---> TMB Communication]---------------------")
        tx_proto_print("Puzzle promise protocol exchange")
        for x in range(1,5):
            bf = random.randrange(1000, 5000)
            tx_proto_print("Blinding factor bf = ", bf," Hash = ",hash(bf))
        for x in range(1,5):
            temp = random.randrange(1000, 5000)
            tx_proto_print("Fake factors = ", temp)
        tx_proto_print("Receiver sending sigma = ",sigmaBob," to get 1 coin")

        receiver_channel.u2t += 1
        receiver_channel.t2u -= 1
        receiver.channel_balance += 1

        tx_proto_print("User with ID "+str(receiver.user_id)+ " recived 1 coin successfully")
        amount-=1

    
    print("\nAfter TX execution:\nInformation about Sender and the channel between Sender and Tumbler:")
    print(vars(sender))
    print(vars(sender_channel))
    print("Information about Receiver and the channel between Tumbler and Receiver:")
    print(vars(receiver))
    print(vars(receiver_channel))

# %%
number_of_users=27
number_of_probers = 8

tumbler = Tumbler(balance=5000)

users = [User(user_id=i, balance=random.randint(50, 200)) for i in range(1, number_of_users+1)]

probers = [User(user_id=i, balance=random.randint(100, 400)) for i in range(number_of_users+1, number_of_users+number_of_probers+1)]

# attacker =  User(user_id=number_of_users+1, balance=300)

users.extend(probers)


print("\nUsers:")
for i in users:
    print(vars(i))
    
print("\nTumbler Info:")
print(vars(tumbler))

# Users deposit funds
for user in users:
    if user.user_id<=number_of_users:
        desposit_amount=random.randint(10, 30)
        tumbler.create_channel(user, desposit_amount)
    else:
        desposit_amount = int(0.8*user.balance)
        tumbler.create_channel(user, desposit_amount)
        

print("\nUsers (after channel formation):")
for i in users:
    print(vars(i))

    
print("\nTumbler Info (after channel formation):")
print(vars(tumbler))

print("\nChannels with the Tumbler:")
for i in tumbler.channels:
    print(vars(i))

    
num_of_txs = 2

while(num_of_txs):
    
    print("\n\n------------------")
    
    random_selection = random.sample(users, 2)
    
    r_sender = random_selection[0]
    r_receiver = random_selection[1]
    
    r_amount = random.randint(1, 10)

#     print("\n\n",random_selection)
    
#     for i in random_selection:
#         print(vars(i))

    
    transction_protocol(sender=r_sender, receiver=r_receiver, tumbler=tumbler, amount = r_amount)
    num_of_txs-=1
# Out:
# Users:
# {'user_id': 1, 'balance': 182, 'channel_balance': 0}
# {'user_id': 2, 'balance': 155, 'channel_balance': 0}
# {'user_id': 3, 'balance': 192, 'channel_balance': 0}
# {'user_id': 4, 'balance': 77, 'channel_balance': 0}
# {'user_id': 5, 'balance': 102, 'channel_balance': 0}
# {'user_id': 6, 'balance': 200, 'channel_balance': 0}
# {'user_id': 7, 'balance': 115, 'channel_balance': 0}
# {'user_id': 8, 'balance': 187, 'channel_balance': 0}
# {'user_id': 9, 'balance': 161, 'channel_balance': 0}
# {'user_id': 10, 'balance': 163, 'channel_balance': 0}
# {'user_id': 11, 'balance': 169, 'channel_balance': 0}
# {'user_id': 12, 'balance': 154, 'channel_balance': 0}
# {'user_id': 13, 'balance': 61, 'channel_balance': 0}
# {'user_id': 14, 'balance': 100, 'channel_balance': 0}
# {'user_id': 15, 'balance': 106, 'channel_balance': 0}
# {'user_id': 16, 'balance': 79, 'channel_balance': 0}
# {'user_id': 17, 'balance': 130, 'channel_balance': 0}
# {'user_id': 18, 'balance': 187, 'channel_balance': 0}
# {'user_id': 19, 'balance': 85, 'channel_balance': 0}
# {'user_id': 20, 'balance': 140, 'channel_balance': 0}
# {'user_id': 21, 'balance': 50, 'channel_balance': 0}
# {'user_id': 22, 'balance': 200, 'channel_balance': 0}
# {'user_id': 23, 'balance': 103, 'channel_balance': 0}
# {'user_id': 24, 'balance': 160, 'channel_balance': 0}
# {'user_id': 25, 'balance': 80, 'channel_balance': 0}
# {'user_id': 26, 'balance': 113, 'channel_balance': 0}
# {'user_id': 27, 'balance': 62, 'channel_balance': 0}
# {'user_id': 28, 'balance': 318, 'channel_balance': 0}
# {'user_id': 29, 'balance': 227, 'channel_balance': 0}
# {'user_id': 30, 'balance': 269, 'channel_balance': 0}
# {'user_id': 31, 'balance': 387, 'channel_balance': 0}
# {'user_id': 32, 'balance': 139, 'channel_balance': 0}
# {'user_id': 33, 'balance': 318, 'channel_balance': 0}
# {'user_id': 34, 'balance': 294, 'channel_balance': 0}
# {'user_id': 35, 'balance': 327, 'channel_balance': 0}
#
# Tumbler Info:
# {'balance': 5000, 'channels': []}
#
# Users (after channel formation):
# {'user_id': 1, 'balance': 159, 'channel_balance': 23}
# {'user_id': 2, 'balance': 138, 'channel_balance': 17}
# {'user_id': 3, 'balance': 180, 'channel_balance': 12}
# {'user_id': 4, 'balance': 55, 'channel_balance': 22}
# {'user_id': 5, 'balance': 79, 'channel_balance': 23}
# {'user_id': 6, 'balance': 181, 'channel_balance': 19}
# {'user_id': 7, 'balance': 89, 'channel_balance': 26}
# {'user_id': 8, 'balance': 170, 'channel_balance': 17}
# {'user_id': 9, 'balance': 151, 'channel_balance': 10}
# {'user_id': 10, 'balance': 140, 'channel_balance': 23}
# {'user_id': 11, 'balance': 151, 'channel_balance': 18}
# {'user_id': 12, 'balance': 138, 'channel_balance': 16}
# {'user_id': 13, 'balance': 35, 'channel_balance': 26}
# {'user_id': 14, 'balance': 75, 'channel_balance': 25}
# {'user_id': 15, 'balance': 87, 'channel_balance': 19}
# {'user_id': 16, 'balance': 64, 'channel_balance': 15}
# {'user_id': 17, 'balance': 104, 'channel_balance': 26}
# {'user_id': 18, 'balance': 159, 'channel_balance': 28}
# {'user_id': 19, 'balance': 62, 'channel_balance': 23}
# {'user_id': 20, 'balance': 121, 'channel_balance': 19}
# {'user_id': 21, 'balance': 33, 'channel_balance': 17}
# {'user_id': 22, 'balance': 185, 'channel_balance': 15}
# {'user_id': 23, 'balance': 73, 'channel_balance': 30}
# {'user_id': 24, 'balance': 137, 'channel_balance': 23}
# {'user_id': 25, 'balance': 68, 'channel_balance': 12}
# {'user_id': 26, 'balance': 86, 'channel_balance': 27}
# {'user_id': 27, 'balance': 36, 'channel_balance': 26}
# {'user_id': 28, 'balance': 64, 'channel_balance': 254}
# {'user_id': 29, 'balance': 46, 'channel_balance': 181}
# {'user_id': 30, 'balance': 54, 'channel_balance': 215}
# {'user_id': 31, 'balance': 78, 'channel_balance': 309}
# {'user_id': 32, 'balance': 28, 'channel_balance': 111}
# {'user_id': 33, 'balance': 64, 'channel_balance': 254}
# {'user_id': 34, 'balance': 59, 'channel_balance': 235}
# {'user_id': 35, 'balance': 66, 'channel_balance': 261}
#
# Tumbler Info (after channel formation):
# {'balance': 2623, 'channels': [<__main__.Channel object at 0x000001DFAE19E4A0>, <__main__.Channel object at 0x000001DFAE1A6800>, <__main__.Channel object at 0x000001DFAE1A6110>, <__main__.Channel object at 0x000001DFAE1A7EE0>, <__main__.Channel object at 0x000001DFAE1A45E0>, <__main__.Channel object at 0x000001DFAE1A46D0>, <__main__.Channel object at 0x000001DFAE1A7A00>, <__main__.Channel object at 0x000001DFAE1A6DD0>, <__main__.Channel object at 0x000001DFAE1A6BF0>, <__main__.Channel object at 0x000001DFAE1A61D0>, <__main__.Channel object at 0x000001DFAE1A7160>, <__main__.Channel object at 0x000001DFAE1A71F0>, <__main__.Channel object at 0x000001DFAE1A72E0>, <__main__.Channel object at 0x000001DFAE1A68F0>, <__main__.Channel object at 0x000001DFAE1A4AF0>, <__main__.Channel object at 0x000001DFAE1A7700>, <__main__.Channel object at 0x000001DFAE1A6AD0>, <__main__.Channel object at 0x000001DFAE1A7F10>, <__main__.Channel object at 0x000001DFAE1A4CA0>, <__main__.Channel object at 0x000001DFAE1A7D90>, <__main__.Channel object at 0x000001DFAE1A6B00>, <__main__.Channel object at 0x000001DFAE1A4D30>, <__main__.Channel object at 0x000001DFAE1A6050>, <__main__.Channel object at 0x000001DFAE1A6C50>, <__main__.Channel object at 0x000001DFAE1A4FA0>, <__main__.Channel object at 0x000001DFAE1A6FB0>, <__main__.Channel object at 0x000001DFAE1A7250>, <__main__.Channel object at 0x000001DFAE1A40A0>, <__main__.Channel object at 0x000001DFAE1A6020>, <__main__.Channel object at 0x000001DFAE1A6B90>, <__main__.Channel object at 0x000001DFAE1A5540>, <__main__.Channel object at 0x000001DFAE0EA590>, <__main__.Channel object at 0x000001DFAE0E9870>, <__main__.Channel object at 0x000001DFAE0E9AE0>, <__main__.Channel object at 0x000001DFAE0E9E40>]}
#
# Channels with the Tumbler:
# {'deposit': 46, 'user': <__main__.User object at 0x000001DFAE19F670>, 'u2t': 23.0, 't2u': 23.0}
# {'deposit': 34, 'user': <__main__.User object at 0x000001DFAE19EB90>, 'u2t': 17.0, 't2u': 17.0}
# {'deposit': 24, 'user': <__main__.User object at 0x000001DFAE19FE50>, 'u2t': 12.0, 't2u': 12.0}
# {'deposit': 44, 'user': <__main__.User object at 0x000001DFAE19D0C0>, 'u2t': 22.0, 't2u': 22.0}
# {'deposit': 46, 'user': <__main__.User object at 0x000001DFAE19FFD0>, 'u2t': 23.0, 't2u': 23.0}
# {'deposit': 38, 'user': <__main__.User object at 0x000001DFAE19F580>, 'u2t': 19.0, 't2u': 19.0}
# {'deposit': 52, 'user': <__main__.User object at 0x000001DFAE19CCA0>, 'u2t': 26.0, 't2u': 26.0}
# {'deposit': 34, 'user': <__main__.User object at 0x000001DFAE19E500>, 'u2t': 17.0, 't2u': 17.0}
# {'deposit': 20, 'user': <__main__.User object at 0x000001DFAE19CFD0>, 'u2t': 10.0, 't2u': 10.0}
# {'deposit': 46, 'user': <__main__.User object at 0x000001DFAE1A6D10>, 'u2t': 23.0, 't2u': 23.0}
# {'deposit': 36, 'user': <__main__.User object at 0x000001DFAE1A4AC0>, 'u2t': 18.0, 't2u': 18.0}
# {'deposit': 32, 'user': <__main__.User object at 0x000001DFAE1A7CD0>, 'u2t': 16.0, 't2u': 16.0}
# {'deposit': 52, 'user': <__main__.User object at 0x000001DFAE1A5FC0>, 'u2t': 26.0, 't2u': 26.0}
# {'deposit': 50, 'user': <__main__.User object at 0x000001DFAE1A7BE0>, 'u2t': 25.0, 't2u': 25.0}
# {'deposit': 38, 'user': <__main__.User object at 0x000001DFAE1A4C10>, 'u2t': 19.0, 't2u': 19.0}
# {'deposit': 30, 'user': <__main__.User object at 0x000001DFAE1A6F20>, 'u2t': 15.0, 't2u': 15.0}
# {'deposit': 52, 'user': <__main__.User object at 0x000001DFAE1A48B0>, 'u2t': 26.0, 't2u': 26.0}
# {'deposit': 56, 'user': <__main__.User object at 0x000001DFAE1A62F0>, 'u2t': 28.0, 't2u': 28.0}
# {'deposit': 46, 'user': <__main__.User object at 0x000001DFAE1A6B60>, 'u2t': 23.0, 't2u': 23.0}
# {'deposit': 38, 'user': <__main__.User object at 0x000001DFAE1A4730>, 'u2t': 19.0, 't2u': 19.0}
# {'deposit': 34, 'user': <__main__.User object at 0x000001DFAE1A57E0>, 'u2t': 17.0, 't2u': 17.0}
# {'deposit': 30, 'user': <__main__.User object at 0x000001DFAE1A5780>, 'u2t': 15.0, 't2u': 15.0}
# {'deposit': 60, 'user': <__main__.User object at 0x000001DFAE1A56F0>, 'u2t': 30.0, 't2u': 30.0}
# {'deposit': 46, 'user': <__main__.User object at 0x000001DFAE1A56C0>, 'u2t': 23.0, 't2u': 23.0}
# {'deposit': 24, 'user': <__main__.User object at 0x000001DFAE1A79A0>, 'u2t': 12.0, 't2u': 12.0}
# {'deposit': 54, 'user': <__main__.User object at 0x000001DFAE1A7790>, 'u2t': 27.0, 't2u': 27.0}
# {'deposit': 52, 'user': <__main__.User object at 0x000001DFAE1A78B0>, 'u2t': 26.0, 't2u': 26.0}
# {'deposit': 508, 'user': <__main__.User object at 0x000001DFAE19FDF0>, 'u2t': 254.0, 't2u': 254.0}
# {'deposit': 362, 'user': <__main__.User object at 0x000001DFAE19EE30>, 'u2t': 181.0, 't2u': 181.0}
# {'deposit': 430, 'user': <__main__.User object at 0x000001DFAE1A7FA0>, 'u2t': 215.0, 't2u': 215.0}
# {'deposit': 618, 'user': <__main__.User object at 0x000001DFAE1A55A0>, 'u2t': 309.0, 't2u': 309.0}
# {'deposit': 222, 'user': <__main__.User object at 0x000001DFAE1A54B0>, 'u2t': 111.0, 't2u': 111.0}
# {'deposit': 508, 'user': <__main__.User object at 0x000001DFAE1A4910>, 'u2t': 254.0, 't2u': 254.0}
# {'deposit': 470, 'user': <__main__.User object at 0x000001DFAE1A4BB0>, 'u2t': 235.0, 't2u': 235.0}
# {'deposit': 522, 'user': <__main__.User object at 0x000001DFAE1A7820>, 'u2t': 261.0, 't2u': 261.0}
#
#
# ------------------
#
#
#
# ***************************************************************
# Sender ID = 28
# Receiver ID = 2
# Amount: 1
# Information about Sender and the channel between Sender and Tumbler:
# {'user_id': 28, 'balance': 64, 'channel_balance': 254}
# {'deposit': 508, 'user': <__main__.User object at 0x000001DFAE19FDF0>, 'u2t': 254.0, 't2u': 254.0}
# Information about Receiver and the channel between Tumbler and Receiver:
# {'user_id': 2, 'balance': 138, 'channel_balance': 17}
# {'deposit': 34, 'user': <__main__.User object at 0x000001DFAE19EB90>, 'u2t': 17.0, 't2u': 17.0}
#
# After TX execution:
# Information about Sender and the channel between Sender and Tumbler:
# {'user_id': 28, 'balance': 64, 'channel_balance': 253}
# {'deposit': 508, 'user': <__main__.User object at 0x000001DFAE19FDF0>, 'u2t': 253.0, 't2u': 255.0}
# Information about Receiver and the channel between Tumbler and Receiver:
# {'user_id': 2, 'balance': 138, 'channel_balance': 18}
# {'deposit': 34, 'user': <__main__.User object at 0x000001DFAE19EB90>, 'u2t': 18.0, 't2u': 16.0}
#
#
# ------------------
#
#
#
# ***************************************************************
# Sender ID = 12
# Receiver ID = 11
# Amount: 9
# Information about Sender and the channel between Sender and Tumbler:
# {'user_id': 12, 'balance': 138, 'channel_balance': 16}
# {'deposit': 32, 'user': <__main__.User object at 0x000001DFAE1A7CD0>, 'u2t': 16.0, 't2u': 16.0}
# Information about Receiver and the channel between Tumbler and Receiver:
# {'user_id': 11, 'balance': 151, 'channel_balance': 18}
# {'deposit': 36, 'user': <__main__.User object at 0x000001DFAE1A4AC0>, 'u2t': 18.0, 't2u': 18.0}
#
# After TX execution:
# Information about Sender and the channel between Sender and Tumbler:
# {'user_id': 12, 'balance': 138, 'channel_balance': 7}
# {'deposit': 32, 'user': <__main__.User object at 0x000001DFAE1A7CD0>, 'u2t': 7.0, 't2u': 25.0}
# Information about Receiver and the channel between Tumbler and Receiver:
# {'user_id': 11, 'balance': 151, 'channel_balance': 27}
# {'deposit': 36, 'user': <__main__.User object at 0x000001DFAE1A4AC0>, 'u2t': 27.0, 't2u': 9.0}

# %%
def balance_probing(attacker, victims, tumbler):
    
    amount_per_probing = attacker.channel_balance/len(victims)
    print("Attacker Info:",vars(attacker))
#     print(amount)
    for victim in victims:
        amount = amount_per_probing
    
        count=0
        low=0
        high = 0
        print("\n\n---------\nVictim Info:",vars(victim))
        while(True):
#             print("\nPretend sending ",amount)
            fake_TX = Transaction(sender=attacker, receiver=victim, amount=amount, consent=False)
            count+=1
            if amount==(victim.channel_balance):
                print("Discovered Amount:",amount)
                break
            elif amount<(victim.channel_balance):
                low=amount
#                 print("Error: \"Fake TX!\" from Alice")
            else:
                high=amount
#                 print("Error: \"Not enough fund!\" from Tumbler")
            amount=int((low+high)/2)
        
     
        print("# of probing TX performed:",count,"\n---------\n")

# %%
def split_list_into_sublists(lst, x):
    # Calculate the size of each sublist
    sublist_size = len(lst) // x
    remainder = len(lst) % x

    sublists = []
    start_index = 0

    # Create sublists
    for i in range(x):
        sublist_length = sublist_size + (1 if i < remainder else 0)
        sublists.append(lst[start_index:start_index + sublist_length])
        start_index += sublist_length

    return sublists

# %%
IDs_of_users = list(range(0, number_of_users))

# Assigns subsets of users for different probers
assignments = split_list_into_sublists(IDs_of_users, number_of_probers)

attacker_id = probers[0].user_id

for victim_subset in assignments:
    victims = []
    attacker = users[attacker_id-1]
    for victim_id in victim_subset:
        victims.append(users[victim_id])
    balance_probing(attacker, victims, tumbler)
    attacker_id+=1
# Out:
# Attacker Info: {'user_id': 28, 'balance': 64, 'channel_balance': 253}
#
#
# ---------
# Victim Info: {'user_id': 1, 'balance': 159, 'channel_balance': 23}
# Discovered Amount: 23
# # of probing TX performed: 4
# ---------
#
#
#
# ---------
# Victim Info: {'user_id': 2, 'balance': 138, 'channel_balance': 18}
# Discovered Amount: 18
# # of probing TX performed: 7
# ---------
#
#
#
# ---------
# Victim Info: {'user_id': 3, 'balance': 180, 'channel_balance': 12}
# Discovered Amount: 12
# # of probing TX performed: 7
# ---------
#
#
#
# ---------
# Victim Info: {'user_id': 4, 'balance': 55, 'channel_balance': 22}
# Discovered Amount: 22
# # of probing TX performed: 7
# ---------
#
# Attacker Info: {'user_id': 29, 'balance': 46, 'channel_balance': 181}
#
#
# ---------
# Victim Info: {'user_id': 5, 'balance': 79, 'channel_balance': 23}
# Discovered Amount: 23
# # of probing TX performed: 6
# ---------
#
#
#
# ---------
# Victim Info: {'user_id': 6, 'balance': 181, 'channel_balance': 19}
# Discovered Amount: 19
# # of probing TX performed: 5
# ---------
#
#
#
# ---------
# Victim Info: {'user_id': 7, 'balance': 89, 'channel_balance': 26}
# Discovered Amount: 26
# # of probing TX performed: 7
# ---------
#
#
#
# ---------
# Victim Info: {'user_id': 8, 'balance': 170, 'channel_balance': 17}
# Discovered Amount: 17
# # of probing TX performed: 6
# ---------
#
# Attacker Info: {'user_id': 30, 'balance': 54, 'channel_balance': 215}
#
#
# ---------
# Victim Info: {'user_id': 9, 'balance': 151, 'channel_balance': 10}
# Discovered Amount: 10
# # of probing TX performed: 7
# ---------
#
#
#
# ---------
# Victim Info: {'user_id': 10, 'balance': 140, 'channel_balance': 23}
# Discovered Amount: 23
# # of probing TX performed: 7
# ---------
#
#
#
# ---------
# Victim Info: {'user_id': 11, 'balance': 151, 'channel_balance': 27}
# Discovered Amount: 27
# # of probing TX performed: 6
# ---------
#
#
#
# ---------
# Victim Info: {'user_id': 12, 'balance': 138, 'channel_balance': 7}
# Discovered Amount: 7
# # of probing TX performed: 6
# ---------
#
# Attacker Info: {'user_id': 31, 'balance': 78, 'channel_balance': 309}
#
#
# ---------
# Victim Info: {'user_id': 13, 'balance': 35, 'channel_balance': 26}
# Discovered Amount: 26
# # of probing TX performed: 7
# ---------
#
#
#
# ---------
# Victim Info: {'user_id': 14, 'balance': 75, 'channel_balance': 25}
# Discovered Amount: 25
# # of probing TX performed: 3
# ---------
#
#
#
# ---------
# Victim Info: {'user_id': 15, 'balance': 87, 'channel_balance': 19}
# Discovered Amount: 19
# # of probing TX performed: 7
# ---------
#
# Attacker Info: {'user_id': 32, 'balance': 28, 'channel_balance': 111}
#
#
# ---------
# Victim Info: {'user_id': 16, 'balance': 64, 'channel_balance': 15}
# Discovered Amount: 15
# # of probing TX performed: 5
# ---------
#
#
#
# ---------
# Victim Info: {'user_id': 17, 'balance': 104, 'channel_balance': 26}
# Discovered Amount: 26
# # of probing TX performed: 7
# ---------
#
#
#
# ---------
# Victim Info: {'user_id': 18, 'balance': 159, 'channel_balance': 28}
# Discovered Amount: 28
# # of probing TX performed: 6
# ---------
#
# Attacker Info: {'user_id': 33, 'balance': 64, 'channel_balance': 254}
#
#
# ---------
# Victim Info: {'user_id': 19, 'balance': 62, 'channel_balance': 23}
# Discovered Amount: 23
# # of probing TX performed: 6
# ---------
#
#
#
# ---------
# Victim Info: {'user_id': 20, 'balance': 121, 'channel_balance': 19}
# Discovered Amount: 19
# # of probing TX performed: 7
# ---------
#
#
#
# ---------
# Victim Info: {'user_id': 21, 'balance': 33, 'channel_balance': 17}
# Discovered Amount: 17
# # of probing TX performed: 8
# ---------
#
# Attacker Info: {'user_id': 34, 'balance': 59, 'channel_balance': 235}
#
#
# ---------
# Victim Info: {'user_id': 22, 'balance': 185, 'channel_balance': 15}
# Discovered Amount: 15
# # of probing TX performed: 7
# ---------
#
#
#
# ---------
# Victim Info: {'user_id': 23, 'balance': 73, 'channel_balance': 30}
# Discovered Amount: 30
# # of probing TX performed: 7
# ---------
#
#
#
# ---------
# Victim Info: {'user_id': 24, 'balance': 137, 'channel_balance': 23}
# Discovered Amount: 23
# # of probing TX performed: 8
# ---------
#
# Attacker Info: {'user_id': 35, 'balance': 66, 'channel_balance': 261}
#
#
# ---------
# Victim Info: {'user_id': 25, 'balance': 68, 'channel_balance': 12}
# Discovered Amount: 12
# # of probing TX performed: 6
# ---------
#
#
#
# ---------
# Victim Info: {'user_id': 26, 'balance': 86, 'channel_balance': 27}
# Discovered Amount: 27
# # of probing TX performed: 7
# ---------
#
#
#
# ---------
# Victim Info: {'user_id': 27, 'balance': 36, 'channel_balance': 26}
# Discovered Amount: 26
# # of probing TX performed: 5
# ---------
